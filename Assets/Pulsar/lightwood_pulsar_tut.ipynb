# %%
import pandas as pd
from lightwood.api.high_level import (
    ProblemDefinition,
    json_ai_from_problem,
    code_from_json_ai,
    predictor_from_code,
)

# Load a pandas dataset
df = pd.read_csv(
    "./pulsar_data_train.csv.zip"
)

realtestdata_df = pd.read_csv("./pulsar_data_test.csv")

df.dropna(inplace=True)

# Define the prediction task by naming the target column
pdef = ProblemDefinition.from_dict(
    {
        "target": "target_class",  # column you want to predict
        "unbias_target": True
    }
)

# Generate JSON-AI code to model the problem
json_ai = json_ai_from_problem(df, problem_definition=pdef)

# OPTIONAL - see the JSON-AI syntax
print(json_ai.to_json())
# Out:
# INFO:lightwood-672:Dropping features: []
# INFO:lightwood-672:Analyzing a sample of 6305
# INFO:lightwood-672:from a total population of 9273, this is equivalent to 68.0% of your data.
# INFO:lightwood-672:Infering type for:  Mean of the integrated profile
# INFO:lightwood-672:Column  Mean of the integrated profile has data type float
# INFO:lightwood-672:Infering type for:  Standard deviation of the integrated profile
# INFO:lightwood-672:Column  Standard deviation of the integrated profile has data type float
# INFO:lightwood-672:Infering type for:  Excess kurtosis of the integrated profile
# INFO:lightwood-672:Column  Excess kurtosis of the integrated profile has data type float
# INFO:lightwood-672:Infering type for:  Skewness of the integrated profile
# INFO:lightwood-672:Column  Skewness of the integrated profile has data type float
# INFO:lightwood-672:Infering type for:  Mean of the DM-SNR curve
# INFO:lightwood-672:Column  Mean of the DM-SNR curve has data type float
# INFO:lightwood-672:Infering type for:  Standard deviation of the DM-SNR curve
# INFO:lightwood-672:Column  Standard deviation of the DM-SNR curve has data type float
# INFO:lightwood-672:Infering type for:  Excess kurtosis of the DM-SNR curve
# INFO:lightwood-672:Column  Excess kurtosis of the DM-SNR curve has data type float
# INFO:lightwood-672:Infering type for:  Skewness of the DM-SNR curve
# INFO:lightwood-672:Column  Skewness of the DM-SNR curve has data type float
# INFO:lightwood-672:Infering type for: target_class
# INFO:lightwood-672:Column target_class has data type binary
# INFO:lightwood-672:Starting statistical analysis
# INFO:lightwood-672:Finished statistical analysis
# {
#     "features": {
#         " Mean of the integrated profile": {
#             "encoder": {
#                 "module": "NumericEncoder",
#                 "args": {}
#             },
#             "data_dtype": "float"
#         },
#         " Standard deviation of the integrated profile": {
#             "encoder": {
#                 "module": "NumericEncoder",
#                 "args": {}
#             },
#             "data_dtype": "float"
#         },
#         " Excess kurtosis of the integrated profile": {
#             "encoder": {
#                 "module": "NumericEncoder",
#                 "args": {}
#             },
#             "data_dtype": "float"
#         },
#         " Skewness of the integrated profile": {
#             "encoder": {
#                 "module": "NumericEncoder",
#                 "args": {}
#             },
#             "data_dtype": "float"
#         },
#         " Mean of the DM-SNR curve": {
#             "encoder": {
#                 "module": "NumericEncoder",
#                 "args": {}
#             },
#             "data_dtype": "float"
#         },
#         " Standard deviation of the DM-SNR curve": {
#             "encoder": {
#                 "module": "NumericEncoder",
#                 "args": {}
#             },
#             "data_dtype": "float"
#         },
#         " Excess kurtosis of the DM-SNR curve": {
#             "encoder": {
#                 "module": "NumericEncoder",
#                 "args": {}
#             },
#             "data_dtype": "float"
#         },
#         " Skewness of the DM-SNR curve": {
#             "encoder": {
#                 "module": "NumericEncoder",
#                 "args": {}
#             },
#             "data_dtype": "float"
#         }
#     },
#     "outputs": {
#         "target_class": {
#             "data_dtype": "binary",
#             "encoder": {
#                 "module": "BinaryEncoder",
#                 "args": {
#                     "is_target": "True",
#                     "target_weights": "$statistical_analysis.target_weights"
#                 }
#             },
#             "mixers": [
#                 {
#                     "module": "Neural",
#                     "args": {
#                         "fit_on_dev": true,
#                         "stop_after": "$problem_definition.seconds_per_mixer",
#                         "search_hyperparameters": true
#                     }
#                 },
#                 {
#                     "module": "LightGBM",
#                     "args": {
#                         "stop_after": "$problem_definition.seconds_per_mixer",
#                         "fit_on_dev": true
#                     }
#                 },
#                 {
#                     "module": "Regression",
#                     "args": {
#                         "stop_after": "$problem_definition.seconds_per_mixer"
#                     }
#                 }
#             ],
#             "ensemble": {
#                 "module": "BestOf",
#                 "args": {
#                     "args": "$pred_args",
#                     "accuracy_functions": "$accuracy_functions",
#                     "ts_analysis": null
#                 }
#             }
#         }
#     },
#     "problem_definition": {
#         "target": "target_class",
#         "pct_invalid": 2,
#         "unbias_target": true,
#         "seconds_per_mixer": 57024.0,
#         "seconds_per_encoder": null,
#         "expected_additional_time": 9.2960946559906,
#         "time_aim": 259200,
#         "target_weights": null,
#         "positive_domain": false,
#         "timeseries_settings": {
#             "is_timeseries": false,
#             "order_by": null,
#             "window": null,
#             "group_by": null,
#             "use_previous_target": true,
#             "nr_predictions": null,
#             "historical_columns": null,
#             "target_type": "",
#             "allow_incomplete_history": false,
#             "eval_cold_start": true,
#             "interval_periods": []
#         },
#         "anomaly_detection": false,
#         "use_default_analysis": true,
#         "ignore_features": [],
#         "fit_on_all": true,
#         "strict_mode": true,
#         "seed_nr": 420
#     },
#     "identifiers": {},
#     "accuracy_functions": [
#         "balanced_accuracy_score"
#     ]
# }

# %%
# Generate python code
code = code_from_json_ai(json_ai)

# OPTIONAL - see generated code
#print(code)

# Create a predictor from python code
predictor = predictor_from_code(code)
# Out:
# INFO:lightwood-672:Unable to import black formatter, predictor code might be a bit ugly.

# %%
# Train a model end-to-end from raw data to a finalized predictor
predictor.learn(df)

# Make the train/test splits and show predictions for a few examples
test_df = predictor.split(predictor.preprocess(df))["test"]
# Out:
# INFO:lightwood-672:Dropping features: []
# INFO:lightwood-672:Performing statistical analysis on data
# INFO:lightwood-672:Starting statistical analysis
# INFO:lightwood-672:Finished statistical analysis
# INFO:lightwood-672:Cleaning the data
# INFO:lightwood-672:Splitting the data into train/test
# INFO:lightwood-672:Preparing the encoders
# INFO:lightwood-672:Encoder prepping dict length of: 1
# INFO:lightwood-672:Encoder prepping dict length of: 2
# INFO:lightwood-672:Encoder prepping dict length of: 3
# INFO:lightwood-672:Encoder prepping dict length of: 4
# INFO:lightwood-672:Encoder prepping dict length of: 5
# INFO:lightwood-672:Encoder prepping dict length of: 6
# INFO:lightwood-672:Encoder prepping dict length of: 7
# INFO:lightwood-672:Encoder prepping dict length of: 8
# INFO:lightwood-672:Encoder prepping dict length of: 9
# INFO:lightwood-672:Done running for: target_class
# INFO:lightwood-672:Done running for:  Mean of the integrated profile
# INFO:lightwood-672:Done running for:  Standard deviation of the integrated profile
# INFO:lightwood-672:Done running for:  Excess kurtosis of the integrated profile
# INFO:lightwood-672:Done running for:  Skewness of the integrated profile
# INFO:lightwood-672:Done running for:  Mean of the DM-SNR curve
# INFO:lightwood-672:Done running for:  Standard deviation of the DM-SNR curve
# INFO:lightwood-672:Done running for:  Excess kurtosis of the DM-SNR curve
# INFO:lightwood-672:Done running for:  Skewness of the DM-SNR curve
# INFO:lightwood-672:Featurizing the data
# INFO:lightwood-672:Training the mixers
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# WARNING:lightwood-672:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# /usr/local/lib/python3.7/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# /usr/local/lib/python3.7/site-packages/pytorch_ranger/ranger.py:172: UserWarning: This overload of addcmul_ is deprecated:
# 	addcmul_(Number value, Tensor tensor1, Tensor tensor2)
# Consider using one of the following signatures instead:
# 	addcmul_(Tensor tensor1, Tensor tensor2, *, Number value) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1025.)
#   exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
# INFO:lightwood-672:Loss of 1.0778766870498657 with learning rate 0.0001
# INFO:lightwood-672:Loss of 1.0385481119155884 with learning rate 0.00014
# INFO:lightwood-672:Loss of 1.1099634170532227 with learning rate 0.00019599999999999997
# INFO:lightwood-672:Found learning rate of: 0.00014
# INFO:lightwood-672:Loss @ epoch 1: 0.8357831478118897
# INFO:lightwood-672:Loss @ epoch 2: 0.6832048535346985
# INFO:lightwood-672:Loss @ epoch 3: 0.5680002570152283
# INFO:lightwood-672:Loss @ epoch 4: 0.47024803757667544
# INFO:lightwood-672:Loss @ epoch 5: 0.40582683086395266
# INFO:lightwood-672:Loss @ epoch 6: 0.36834020614624025
# INFO:lightwood-672:Loss @ epoch 7: 0.33686886727809906
# INFO:lightwood-672:Loss @ epoch 8: 0.3143029183149338
# INFO:lightwood-672:Loss @ epoch 9: 0.29977230727672577
# INFO:lightwood-672:Loss @ epoch 10: 0.28627285063266755
# INFO:lightwood-672:Loss @ epoch 11: 0.2755600243806839
# INFO:lightwood-672:Loss @ epoch 12: 0.26809552013874055
# INFO:lightwood-672:Loss @ epoch 13: 0.26070611774921415
# INFO:lightwood-672:Loss @ epoch 14: 0.2544901132583618
# INFO:lightwood-672:Loss @ epoch 15: 0.24999355971813203
# INFO:lightwood-672:Loss @ epoch 16: 0.2454291820526123
# INFO:lightwood-672:Loss @ epoch 105: 0.19538419544696808
# INFO:lightwood-672:Loss @ epoch 106: 0.19539907276630403
# INFO:lightwood-672:Loss @ epoch 107: 0.19527130275964738
# INFO:lightwood-672:Loss @ epoch 108: 0.19512615650892257
# INFO:lightwood-672:Loss @ epoch 109: 0.19514969140291213
# INFO:lightwood-672:Loss @ epoch 110: 0.1950266808271408
# INFO:lightwood-672:Loss @ epoch 111: 0.19488531053066255
# INFO:lightwood-672:Loss @ epoch 112: 0.19491249173879624
# INFO:lightwood-672:Loss @ epoch 113: 0.19479280859231948
# INFO:lightwood-672:Loss @ epoch 114: 0.19465765804052354
# INFO:lightwood-672:Loss @ epoch 115: 0.19469377994537354
# INFO:lightwood-672:Loss @ epoch 116: 0.19458120912313462
# INFO:lightwood-672:Loss @ epoch 117: 0.19444870501756667
# INFO:lightwood-672:Loss @ epoch 118: 0.19449086487293243
# INFO:lightwood-672:Loss @ epoch 119: 0.1943866416811943
# INFO:lightwood-672:Loss @ epoch 120: 0.19425821155309678
# INFO:lightwood-672:Loss @ epoch 121: 0.19430778473615645
# INFO:lightwood-672:Loss @ epoch 122: 0.19420796781778335
# INFO:lightwood-672:Loss @ epoch 123: 0.19408171772956848
# INFO:lightwood-672:Loss @ epoch 124: 0.1941403403878212
# INFO:lightwood-672:Loss @ epoch 125: 0.1940513402223587
# INFO:lightwood-672:Loss @ epoch 126: 0.19393173456192017
# INFO:lightwood-672:Loss @ epoch 127: 0.1940010145306587
# INFO:lightwood-672:Loss @ epoch 128: 0.19391388148069383
# INFO:lightwood-672:Loss @ epoch 129: 0.19379721581935883
# INFO:lightwood-672:Loss @ epoch 130: 0.1938694402575493
# INFO:lightwood-672:Loss @ epoch 1: 0.1642419486061523
# INFO:lightwood-672:Loss @ epoch 2: 0.16436650211873807
# INFO:lightwood-672:Loss @ epoch 3: 0.16557254416770056
# INFO:lightwood-672:Loss @ epoch 4: 0.1665706204152421
# INFO:lightwood-672:Loss @ epoch 5: 0.1666617525839492
# INFO:lightwood-672:Started fitting LGBM model
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-672:A single GBM iteration takes 0.21735405921936035 seconds
# INFO:lightwood-672:Training GBM (<module 'optuna.integration.lightgbm' from '/usr/local/lib/python3.7/site-packages/optuna/integration/lightgbm.py'>) with 104936 iterations given 57021.00764346123 seconds constraint
# feature_fraction, val_score: inf:   0%|          | 0/7 [00:00<?, ?it/s]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# feature_fraction, val_score: 0.104420:  14%|#4        | 1/7 [00:01<00:07,  1.21s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# feature_fraction, val_score: 0.096299:  29%|##8       | 2/7 [00:02<00:06,  1.30s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# feature_fraction, val_score: 0.096299:  43%|####2     | 3/7 [00:04<00:05,  1.33s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# feature_fraction, val_score: 0.096299:  57%|#####7    | 4/7 [00:05<00:03,  1.32s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# feature_fraction, val_score: 0.082463:  71%|#######1  | 5/7 [00:06<00:02,  1.37s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# feature_fraction, val_score: 0.082463:  86%|########5 | 6/7 [00:08<00:01,  1.38s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# feature_fraction, val_score: 0.082463: 100%|##########| 7/7 [00:09<00:00,  1.39s/it]
# num_leaves, val_score: 0.082463:   0%|          | 0/20 [00:00<?, ?it/s]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# num_leaves, val_score: 0.082463:   5%|5         | 1/20 [00:01<00:30,  1.60s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# num_leaves, val_score: 0.082463:  10%|#         | 2/20 [00:03<00:28,  1.57s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# num_leaves, val_score: 0.082463:  15%|#5        | 3/20 [00:04<00:26,  1.55s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# num_leaves, val_score: 0.082463:  20%|##        | 4/20 [00:06<00:24,  1.55s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# num_leaves, val_score: 0.082463:  25%|##5       | 5/20 [00:07<00:23,  1.55s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# num_leaves, val_score: 0.082463:  30%|###       | 6/20 [00:09<00:21,  1.57s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# num_leaves, val_score: 0.082463:  35%|###5      | 7/20 [00:10<00:20,  1.57s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# num_leaves, val_score: 0.082463:  40%|####      | 8/20 [00:12<00:19,  1.61s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# num_leaves, val_score: 0.082463:  45%|####5     | 9/20 [00:14<00:17,  1.59s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# num_leaves, val_score: 0.082463:  50%|#####     | 10/20 [00:15<00:15,  1.58s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# num_leaves, val_score: 0.082463:  55%|#####5    | 11/20 [00:17<00:13,  1.53s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# num_leaves, val_score: 0.082463:  60%|######    | 12/20 [00:18<00:12,  1.52s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# num_leaves, val_score: 0.082463:  65%|######5   | 13/20 [00:20<00:10,  1.51s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# num_leaves, val_score: 0.082463:  70%|#######   | 14/20 [00:21<00:08,  1.47s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# num_leaves, val_score: 0.082463:  75%|#######5  | 15/20 [00:23<00:07,  1.49s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# num_leaves, val_score: 0.082463:  80%|########  | 16/20 [00:24<00:05,  1.46s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# num_leaves, val_score: 0.082463:  85%|########5 | 17/20 [00:25<00:04,  1.47s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# num_leaves, val_score: 0.082463:  90%|######### | 18/20 [00:27<00:02,  1.46s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# num_leaves, val_score: 0.060895:  95%|#########5| 19/20 [00:29<00:01,  1.56s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# num_leaves, val_score: 0.060895: 100%|##########| 20/20 [00:30<00:00,  1.53s/it]
# bagging, val_score: 0.060895:   0%|          | 0/10 [00:00<?, ?it/s]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# bagging, val_score: 0.060895:  10%|#         | 1/10 [00:01<00:13,  1.51s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# bagging, val_score: 0.060895:  20%|##        | 2/10 [00:03<00:12,  1.51s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# bagging, val_score: 0.060895:  30%|###       | 3/10 [00:04<00:10,  1.45s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# bagging, val_score: 0.060895:  40%|####      | 4/10 [00:05<00:08,  1.49s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# bagging, val_score: 0.060895:  50%|#####     | 5/10 [00:07<00:07,  1.49s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# bagging, val_score: 0.060895:  60%|######    | 6/10 [00:09<00:06,  1.59s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# bagging, val_score: 0.060895:  70%|#######   | 7/10 [00:10<00:04,  1.51s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# bagging, val_score: 0.060895:  80%|########  | 8/10 [00:12<00:02,  1.47s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# bagging, val_score: 0.060895:  90%|######### | 9/10 [00:13<00:01,  1.44s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# bagging, val_score: 0.060895: 100%|##########| 10/10 [00:14<00:00,  1.47s/it]
# feature_fraction_stage2, val_score: 0.060895:   0%|          | 0/6 [00:00<?, ?it/s]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# feature_fraction_stage2, val_score: 0.060895:  17%|#6        | 1/6 [00:01<00:08,  1.61s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# feature_fraction_stage2, val_score: 0.060895:  33%|###3      | 2/6 [00:03<00:06,  1.60s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# feature_fraction_stage2, val_score: 0.060895:  50%|#####     | 3/6 [00:04<00:04,  1.61s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# feature_fraction_stage2, val_score: 0.060895:  67%|######6   | 4/6 [00:06<00:03,  1.60s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# feature_fraction_stage2, val_score: 0.060895:  83%|########3 | 5/6 [00:07<00:01,  1.56s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# feature_fraction_stage2, val_score: 0.060895: 100%|##########| 6/6 [00:09<00:00,  1.55s/it]
# regularization_factors, val_score: 0.060895:   0%|          | 0/20 [00:00<?, ?it/s]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# regularization_factors, val_score: 0.060895:   5%|5         | 1/20 [00:01<00:29,  1.56s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# regularization_factors, val_score: 0.060895:  10%|#         | 2/20 [00:02<00:27,  1.51s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# regularization_factors, val_score: 0.060895:  15%|#5        | 3/20 [00:04<00:25,  1.51s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# regularization_factors, val_score: 0.060895:  20%|##        | 4/20 [00:06<00:25,  1.60s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# regularization_factors, val_score: 0.060895:  25%|##5       | 5/20 [00:07<00:23,  1.54s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# regularization_factors, val_score: 0.060895:  30%|###       | 6/20 [00:09<00:20,  1.50s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# regularization_factors, val_score: 0.060895:  35%|###5      | 7/20 [00:10<00:20,  1.55s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# regularization_factors, val_score: 0.060895:  40%|####      | 8/20 [00:12<00:18,  1.54s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# regularization_factors, val_score: 0.060895:  45%|####5     | 9/20 [00:13<00:16,  1.54s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# regularization_factors, val_score: 0.060895:  50%|#####     | 10/20 [00:15<00:15,  1.55s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# regularization_factors, val_score: 0.060895:  55%|#####5    | 11/20 [00:17<00:14,  1.59s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# regularization_factors, val_score: 0.060895:  60%|######    | 12/20 [00:18<00:12,  1.60s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# regularization_factors, val_score: 0.060895:  65%|######5   | 13/20 [00:20<00:11,  1.60s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# regularization_factors, val_score: 0.060895:  70%|#######   | 14/20 [00:21<00:09,  1.60s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# regularization_factors, val_score: 0.060895:  75%|#######5  | 15/20 [00:23<00:07,  1.58s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# regularization_factors, val_score: 0.060895:  80%|########  | 16/20 [00:25<00:06,  1.61s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# regularization_factors, val_score: 0.060895:  85%|########5 | 17/20 [00:26<00:04,  1.61s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# regularization_factors, val_score: 0.060895:  90%|######### | 18/20 [00:28<00:03,  1.56s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# regularization_factors, val_score: 0.060895:  95%|#########5| 19/20 [00:29<00:01,  1.61s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# regularization_factors, val_score: 0.060895: 100%|##########| 20/20 [00:31<00:00,  1.56s/it]
# min_data_in_leaf, val_score: 0.060895:   0%|          | 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# min_data_in_leaf, val_score: 0.060895:  20%|##        | 1/5 [00:01<00:05,  1.28s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# min_data_in_leaf, val_score: 0.060895:  40%|####      | 2/5 [00:02<00:04,  1.36s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# min_data_in_leaf, val_score: 0.059912:  60%|######    | 3/5 [00:04<00:03,  1.51s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# min_data_in_leaf, val_score: 0.059912:  80%|########  | 4/5 [00:06<00:01,  1.51s/it]/usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# min_data_in_leaf, val_score: 0.059912: 100%|##########| 5/5 [00:07<00:00,  1.59s/it]
# INFO:lightwood-672:Lightgbm model contains 63 weak estimators
# INFO:lightwood-672:Updating lightgbm model with 1 iterations
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-672:Model now has a total of 66 weak estimators
# WARNING:lightwood-672:Exception: Unspported binary type for regression when training mixer: <lightwood.mixer.regression.Regression object at 0x7fc6c4f25a50>
# INFO:lightwood-672:Ensembling the mixer
# INFO:lightwood-672:Mixer: Neural got accuracy: 0.9298938102556937
# INFO:lightwood-672:Mixer: LightGBM got accuracy: 0.9123026407712729
# INFO:lightwood-672:Picked best mixer: Neural
# INFO:lightwood-672:Analyzing the ensemble of mixers
# INFO:lightwood-672:The block ICP is now running its analyze() method
# INFO:lightwood-672:The block AccStats is now running its analyze() method
# INFO:lightwood-672:Adjustment on validation requested.
# INFO:lightwood-672:Updating the mixers
# /usr/local/lib/python3.7/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# INFO:lightwood-672:Loss @ epoch 1: 0.16823539111231053
# INFO:lightwood-672:Loss @ epoch 2: 0.16830391623079777
# INFO:lightwood-672:Loss @ epoch 3: 0.1675131255317302
# INFO:lightwood-672:Loss @ epoch 4: 0.16925438058873019
# INFO:lightwood-672:Loss @ epoch 5: 0.16558278050451053
# INFO:lightwood-672:Loss @ epoch 6: 0.16883682840991587
# INFO:lightwood-672:Updating lightgbm model with 1 iterations
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /usr/local/lib/python3.7/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-672:Model now has a total of 69 weak estimators
# INFO:lightwood-672:Cleaning the data
# INFO:lightwood-672:Splitting the data into train/test

# %%
preds = predictor.predict(realtestdata_df)

print(preds)
# Out:
# INFO:lightwood-3164:Dropping features: []
# INFO:lightwood-3164:Cleaning the data
# INFO:lightwood-3164:Featurizing the data
# INFO:lightwood-3164:The block ICP is now running its explain() method
# INFO:lightwood-3164:The block AccStats is now running its explain() method
# INFO:lightwood-3164:AccStats.explain() has not been implemented, no modifications will be done to the data insights.
#       original_index prediction  __mdb_proba_0.0  __mdb_proba_1.0  confidence
# 0                  0        0.0        -2.599891         3.599891    0.553191
# 1                  1        1.0       -14.581289        15.581289    0.968431
# 2                  2        0.0        -1.393124         2.393124    0.319149
# 3                  3        1.0         1.371195        -0.371195    0.148936
# 4                  4        0.0        -0.763157         1.763157    0.202128
# ...              ...        ...              ...              ...         ...
# 5365            5365        0.0        -4.569973         5.569973    0.851064
# 5366            5366        0.0        -1.754324         2.754324    0.393617
# 5367            5367        0.0        -0.871799         1.871799    0.212766
# 5368            5368        0.0        -2.236572         3.236572    0.489362
# 5369            5369        0.0        -0.990976         1.990976    0.234043
#
# [5370 rows x 5 columns]

# %%
# Save predictor for later use

predictor.save("./pulsars_model")

# %%
preds.to_csv("test_predictations.csv")
