# %% [markdown]
# # Pulsars ML

# %%
from sqlalchemy import create_engine
import pandas as pd
# engine = create_engine('sqlite:///college.db', echo = True)
username='postgres'
password='changeme'
db='Pulsars'
tablename='Pulsars'

# database connection
engine = create_engine(
    f"postgresql+psycopg2://{username}:{password}@localhost:5433/{db}",
    isolation_level="SERIALIZABLE",
)

file_url = './pulsar_data_train.csv.zip'
df = pd.read_csv(file_url, dtype=float)

df.columns
# Out:
# Index([' Mean of the integrated profile',
#        ' Standard deviation of the integrated profile',
#        ' Excess kurtosis of the integrated profile',
#        ' Skewness of the integrated profile', ' Mean of the DM-SNR curve',
#        ' Standard deviation of the DM-SNR curve',
#        ' Excess kurtosis of the DM-SNR curve', ' Skewness of the DM-SNR curve',
#        'target_class'],
#       dtype='object')

# %%
columns = {' Mean of the integrated profile': 'mean_integ_prf',
       ' Standard deviation of the integrated profile': 'std_dev_integ_prf',
       ' Excess kurtosis of the integrated profile': 'ex_kurtosis_integ_prf',
       ' Skewness of the integrated profile': 'sk_integ_prf', 
       ' Mean of the DM-SNR curve': 'mean_dm_snr_curve',
       ' Standard deviation of the DM-SNR curve': 'std_dev_dm_snr_curve',
       ' Excess kurtosis of the DM-SNR curve': 'ex_kurtosis_dm_snr_curve', 
       ' Skewness of the DM-SNR curve': 'sk_dm_snr_curve'}
df.rename(columns=columns, inplace=True, errors="raise")

# %%
df.dropna(inplace=True)

df.to_sql(tablename,con=engine, if_exists='replace', index=False)

# %%
df.to_dict(orient='records')
# Out:
# [{'mean_integ_prf': 121.15625,
#   'std_dev_integ_prf': 48.37297113,
#   'ex_kurtosis_integ_prf': 0.375484665,
#   'sk_integ_prf': -0.013165489,
#   'mean_dm_snr_curve': 3.168896321,
#   'std_dev_dm_snr_curve': 18.399366600000004,
#   'ex_kurtosis_dm_snr_curve': 7.4498741489999984,
#   'sk_dm_snr_curve': 65.15929771,
#   'target_class': 0.0},
#  {'mean_integ_prf': 76.96875,
#   'std_dev_integ_prf': 36.17555664,
#   'ex_kurtosis_integ_prf': 0.71289786,
#   'sk_integ_prf': 3.3887185630000003,
#   'mean_dm_snr_curve': 2.399665552,
#   'std_dev_dm_snr_curve': 17.57099693,
#   'ex_kurtosis_dm_snr_curve': 9.414652256,
#   'sk_dm_snr_curve': 102.7229747,
#   'target_class': 0.0},
#  {'mean_integ_prf': 130.5859375,
#   'std_dev_integ_prf': 53.22953353,
#   'ex_kurtosis_integ_prf': 0.133408289,
#   'sk_integ_prf': -0.297241641,
#   'mean_dm_snr_curve': 2.743311037,
#   'std_dev_dm_snr_curve': 22.36255299,
#   'ex_kurtosis_dm_snr_curve': 8.508363784,
#   'sk_dm_snr_curve': 74.03132420000001,
#   'target_class': 0.0},
#  {'mean_integ_prf': 84.8046875,
#   'std_dev_integ_prf': 36.11765898,
#   'ex_kurtosis_integ_prf': 0.825012787,
#   'sk_integ_prf': 3.274125373,
#   'mean_dm_snr_curve': 2.790133779,
#   'std_dev_dm_snr_curve': 20.61800857,
#   'ex_kurtosis_dm_snr_curve': 8.405008383,
#   'sk_dm_snr_curve': 76.29112787,
#   'target_class': 0.0},
#  {'mean_integ_prf': 109.40625,
#   'std_dev_integ_prf': 55.91252061,
#   'ex_kurtosis_integ_prf': 0.565105947,
#   'sk_integ_prf': 0.056246664,
#   'mean_dm_snr_curve': 2.797658863,
#   'std_dev_dm_snr_curve': 19.49652729,
#   'ex_kurtosis_dm_snr_curve': 9.443282129,
#   'sk_dm_snr_curve': 97.37457842,
#   'target_class': 0.0},
#  {'mean_integ_prf': 95.0078125,
#   'std_dev_integ_prf': 40.21980546,
#   'ex_kurtosis_integ_prf': 0.3475781,
#   'sk_integ_prf': 1.1531643809999998,
#   'mean_dm_snr_curve': 2.77006689,
#   'std_dev_dm_snr_curve': 18.21774119,
#   'ex_kurtosis_dm_snr_curve': 7.85120501,
#   'sk_dm_snr_curve': 70.80193775,
#   'target_class': 0.0},
#  {'mean_integ_prf': 130.0859375,
#   'std_dev_integ_prf': 46.40262441,
#   'ex_kurtosis_integ_prf': -0.046584830999999986,
#   'sk_integ_prf': -0.034468391,
#   'mean_dm_snr_curve': 5.050167224,
#   'std_dev_dm_snr_curve': 27.99747644,
#   'ex_kurtosis_dm_snr_curve': 6.059849442999999,
#   'sk_dm_snr_curve': 38.15478586,
#   'target_class': 0.0},
#  {'mean_integ_prf': 96.9375,
#   'std_dev_integ_prf': 40.53735738,
#   'ex_kurtosis_integ_prf': 0.419405572,
#   'sk_integ_prf': 0.755829381,
#   'mean_dm_snr_curve': 1.971571906,
#   'std_dev_dm_snr_curve': 11.63696371,
#   'ex_kurtosis_dm_snr_curve': 11.62911954,
#   'sk_dm_snr_curve': 202.68664,
#   'target_class': 0.0},
#  {'mean_integ_prf': 146.6953125,
#   'std_dev_integ_prf': 47.80617746,
#   'ex_kurtosis_integ_prf': -0.468418783,
#   'sk_integ_prf': 0.554926309,
#   'mean_dm_snr_curve': 2.885451505,
#   'std_dev_dm_snr_curve': 18.04378053,
#   'ex_kurtosis_dm_snr_curve': 9.792420652,
#   'sk_dm_snr_curve': 112.6258021,
#   'target_class': 0.0},
#  {'mean_integ_prf': 102.3671875,
#   'std_dev_integ_prf': 49.842074200000006,
#   'ex_kurtosis_integ_prf': 0.32951523,
#   'sk_integ_prf': 0.180464824,
#   'mean_dm_snr_curve': 1.918896321,
#   'std_dev_dm_snr_curve': 14.84679658,
#   'ex_kurtosis_dm_snr_curve': 11.04450759,
#   'sk_dm_snr_curve': 141.93611909999996,
#   'target_class': 0.0},
#  {'mean_integ_prf': 125.609375,
#   'std_dev_integ_prf': 53.51478102,
#   'ex_kurtosis_integ_prf': 0.109210844,
#   'sk_integ_prf': -0.413431636,
#   'mean_dm_snr_curve': 2.2466555180000003,
#   'std_dev_dm_snr_curve': 13.53869213,
#   'ex_kurtosis_dm_snr_curve': 9.713802964,
#   'sk_dm_snr_curve': 129.5236723,
#   'target_class': 0.0},
#  {'mean_integ_prf': 150.09375,
#   'std_dev_integ_prf': 56.70047915,
#   'ex_kurtosis_integ_prf': -0.256682808,
#   'sk_integ_prf': -0.59470588,
#   'mean_dm_snr_curve': 137.1488294,
#   'std_dev_dm_snr_curve': 51.22345555,
#   'ex_kurtosis_dm_snr_curve': -0.5409186770000001,
#   'sk_dm_snr_curve': 0.598846574,
#   'target_class': 0.0},
#  {'mean_integ_prf': 104.5625,
#   'std_dev_integ_prf': 46.65879305,
#   'ex_kurtosis_integ_prf': 0.35050536,
#   'sk_integ_prf': 0.165345961,
#   'mean_dm_snr_curve': 0.473244147,
#   'std_dev_dm_snr_curve': 9.305756832,
#   'ex_kurtosis_dm_snr_curve': 22.81086106,
#   'sk_dm_snr_curve': 559.6798641,
#   'target_class': 0.0},
#  {'mean_integ_prf': 133.125,
#   'std_dev_integ_prf': 59.95727646,
#   'ex_kurtosis_integ_prf': 0.012855051,
#   'sk_integ_prf': -0.804890239,
#   'mean_dm_snr_curve': 31.55351171,
#   'std_dev_dm_snr_curve': 65.2362543,
#   'ex_kurtosis_dm_snr_curve': 1.73517963,
#   'sk_dm_snr_curve': 1.35850768,
#   'target_class': 0.0},
#  {'mean_integ_prf': 125.1484375,
#   'std_dev_integ_prf': 46.00001526,
#   'ex_kurtosis_integ_prf': 0.114333106,
#   'sk_integ_prf': -0.041770772000000005,
#   'mean_dm_snr_curve': 3.218227425,
#   'std_dev_dm_snr_curve': 17.95311719,
#   'ex_kurtosis_dm_snr_curve': 7.517878845,
#   'sk_dm_snr_curve': 69.18786779,
#   'target_class': 0.0},
#  {'mean_integ_prf': 99.28125,
#   'std_dev_integ_prf': 71.95646877,
#   'ex_kurtosis_integ_prf': 0.765557849,
#   'sk_integ_prf': -0.82764003,
#   'mean_dm_snr_curve': 197.2341137,
#   'std_dev_dm_snr_curve': 63.75879799,
#   'ex_kurtosis_dm_snr_curve': -1.876387679,
#   'sk_dm_snr_curve': 2.431296609,
#   'target_class': 0.0},
#  {'mean_integ_prf': 111.7109375,
#   'std_dev_integ_prf': 46.57053661,
#   'ex_kurtosis_integ_prf': 0.272860629,
#   'sk_integ_prf': -0.061646003,
#   'mean_dm_snr_curve': 2.139632107,
#   'std_dev_dm_snr_curve': 16.65571305,
#   'ex_kurtosis_dm_snr_curve': 9.353872066000001,
#   'sk_dm_snr_curve': 97.73376005,
#   'target_class': 0.0},
#  {'mean_integ_prf': 127.328125,
#   'std_dev_integ_prf': 45.33953665,
#   'ex_kurtosis_integ_prf': -0.02866461,
#   'sk_integ_prf': -0.206532229,
#   'mean_dm_snr_curve': 3.955685619,
#   'std_dev_dm_snr_curve': 26.25178209,
#   'ex_kurtosis_dm_snr_curve': 6.815905214,
#   'sk_dm_snr_curve': 46.62379063,
#   'target_class': 0.0},
#  {'mean_integ_prf': 101.9140625,
#   'std_dev_integ_prf': 52.23953653,
#   'ex_kurtosis_integ_prf': 0.21674266,
#   'sk_integ_prf': -0.291253721,
#   'mean_dm_snr_curve': 9.372073579,
#   'std_dev_dm_snr_curve': 35.10621041,
#   'ex_kurtosis_dm_snr_curve': 4.12515696,
#   'sk_dm_snr_curve': 16.64677944,
#   'target_class': 0.0},
#  {'mean_integ_prf': 108.7421875,
#   'std_dev_integ_prf': 47.58910164,
#   'ex_kurtosis_integ_prf': 0.462444242,
#   'sk_integ_prf': 0.245138892,
#   'mean_dm_snr_curve': 17.37959866,
#   'std_dev_dm_snr_curve': 51.98174414,
#   'ex_kurtosis_dm_snr_curve': 2.84873868,
#   'sk_dm_snr_curve': 6.628034558,
#   'target_class': 0.0},
#  {'mean_integ_prf': 128.484375,
#   'std_dev_integ_prf': 50.99141845,
#   'ex_kurtosis_integ_prf': 0.058376664,
#   'sk_integ_prf': -0.495919613,
#   'mean_dm_snr_curve': 1.7566889630000002,
#   'std_dev_dm_snr_curve': 16.89744287,
#   'ex_kurtosis_dm_snr_curve': 11.75806781,
#   'sk_dm_snr_curve': 152.8897009,
#   'target_class': 0.0},
#  {'mean_integ_prf': 102.234375,
#   'std_dev_integ_prf': 44.50780907,
#   'ex_kurtosis_integ_prf': 0.543618819,
#   'sk_integ_prf': 0.4555624720000001,
#   'mean_dm_snr_curve': 4.75083612,
#   'std_dev_dm_snr_curve': 28.10226412,
#   'ex_kurtosis_dm_snr_curve': 6.250715402999999,
#   'sk_dm_snr_curve': 39.41359715,
#   'target_class': 0.0},
#  {'mean_integ_prf': 98.5703125,
#   'std_dev_integ_prf': 45.06950944,
#   'ex_kurtosis_integ_prf': 0.349156883,
#   'sk_integ_prf': 0.853318645,
#   'mean_dm_snr_curve': 1.815217391,
#   'std_dev_dm_snr_curve': 13.49266378,
#   'ex_kurtosis_dm_snr_curve': 10.80026393,
#   'sk_dm_snr_curve': 146.393325,
#   'target_class': 0.0},
#  {'mean_integ_prf': 36.7109375,
#   'std_dev_integ_prf': 38.26024216,
#   'ex_kurtosis_integ_prf': 4.363306569,
#   'sk_integ_prf': 20.29698008,
#   'mean_dm_snr_curve': 107.2123746,
#   'std_dev_dm_snr_curve': 74.62119531,
#   'ex_kurtosis_dm_snr_curve': 0.115883054,
#   'sk_dm_snr_curve': -0.819637695,
#   'target_class': 1.0},
#  {'mean_integ_prf': 108.7578125,
#   'std_dev_integ_prf': 47.47083744,
#   'ex_kurtosis_integ_prf': 0.233883385,
#   'sk_integ_prf': -0.011839737,
#   'mean_dm_snr_curve': 3.4289297660000004,
#   'std_dev_dm_snr_curve': 22.80572595,
#   'ex_kurtosis_dm_snr_curve': 7.431087285,
#   'sk_dm_snr_curve': 58.33907469,
#   'target_class': 0.0},
#  {'mean_integ_prf': 117.6796875,
#   'std_dev_integ_prf': 47.45704202,
#   'ex_kurtosis_integ_prf': 0.214801403,
#   'sk_integ_prf': -0.13550329,
#   'mean_dm_snr_curve': 2.731605351,
#   'std_dev_dm_snr_curve': 21.99328807,
#   'ex_kurtosis_dm_snr_curve': 8.401668908,
#   'sk_dm_snr_curve': 71.5876406,
#   'target_class': 0.0},
#  {'mean_integ_prf': 43.5,
#   'std_dev_integ_prf': 28.49122672,
#   'ex_kurtosis_integ_prf': 4.334565003,
#   'sk_integ_prf': 26.33986977,
#   'mean_dm_snr_curve': 39.58528428,
#   'std_dev_dm_snr_curve': 75.5334114,
#   'ex_kurtosis_dm_snr_curve': 1.706101856,
#   'sk_dm_snr_curve': 1.403351821,
#   'target_class': 1.0},
#  {'mean_integ_prf': 121.5546875,
#   'std_dev_integ_prf': 58.891294,
#   'ex_kurtosis_integ_prf': 0.013886214,
#   'sk_integ_prf': -0.71180853,
#   'mean_dm_snr_curve': 3.219063545,
#   'std_dev_dm_snr_curve': 19.52642934,
#   'ex_kurtosis_dm_snr_curve': 7.775510532,
#   'sk_dm_snr_curve': 69.80281758,
#   'target_class': 0.0},
#  {'mean_integ_prf': 84.546875,
#   'std_dev_integ_prf': 35.81045138,
#   'ex_kurtosis_integ_prf': 0.90360292,
#   'sk_integ_prf': 2.969175667,
#   'mean_dm_snr_curve': 1.196488294,
#   'std_dev_dm_snr_curve': 12.17894811,
#   'ex_kurtosis_dm_snr_curve': 13.95346437,
#   'sk_dm_snr_curve': 228.9704449,
#   'target_class': 0.0},
#  {'mean_integ_prf': 66.8515625,
#   'std_dev_integ_prf': 58.08803796,
#   'ex_kurtosis_integ_prf': 1.802132263,
#   'sk_integ_prf': 2.232983407,
#   'mean_dm_snr_curve': 67.02090301,
#   'std_dev_dm_snr_curve': 80.61287231,
#   'ex_kurtosis_dm_snr_curve': 0.841739875,
#   'sk_dm_snr_curve': -0.637751734,
#   'target_class': 1.0},
#  {'mean_integ_prf': 135.265625,
#   'std_dev_integ_prf': 50.1224258,
#   'ex_kurtosis_integ_prf': -0.101259289,
#   'sk_integ_prf': -0.398289737,
#   'mean_dm_snr_curve': 2.705685619,
#   'std_dev_dm_snr_curve': 14.41809996,
#   'ex_kurtosis_dm_snr_curve': 8.357114893,
#   'sk_dm_snr_curve': 99.26768573,
#   'target_class': 0.0},
#  {'mean_integ_prf': 105.2734375,
#   'std_dev_integ_prf': 48.25303016,
#   'ex_kurtosis_integ_prf': 0.512676158,
#   'sk_integ_prf': 0.450317547,
#   'mean_dm_snr_curve': 2.418896321,
#   'std_dev_dm_snr_curve': 17.69773933,
#   'ex_kurtosis_dm_snr_curve': 8.490664705,
#   'sk_dm_snr_curve': 81.51229523,
#   'target_class': 0.0},
#  {'mean_integ_prf': 142.96875,
#   'std_dev_integ_prf': 41.55849370000001,
#   'ex_kurtosis_integ_prf': -0.343295424,
#   'sk_integ_prf': 0.391281115,
#   'mean_dm_snr_curve': 7.115384615,
#   'std_dev_dm_snr_curve': 32.01745026,
#   'ex_kurtosis_dm_snr_curve': 4.747219416,
#   'sk_dm_snr_curve': 22.29795865,
#   'target_class': 0.0},
#  {'mean_integ_prf': 107.171875,
#   'std_dev_integ_prf': 41.14268415,
#   'ex_kurtosis_integ_prf': 0.4218090820000001,
#   'sk_integ_prf': 1.514337381,
#   'mean_dm_snr_curve': 1.316889632,
#   'std_dev_dm_snr_curve': 11.16697902,
#   'ex_kurtosis_dm_snr_curve': 13.66969118,
#   'sk_dm_snr_curve': 250.5981445,
#   'target_class': 0.0},
#  {'mean_integ_prf': 126.2734375,
#   'std_dev_integ_prf': 49.21790116,
#   'ex_kurtosis_integ_prf': 0.028076659,
#   'sk_integ_prf': -0.176735487,
#   'mean_dm_snr_curve': 2.432274247,
#   'std_dev_dm_snr_curve': 13.37919797,
#   'ex_kurtosis_dm_snr_curve': 9.203359217000001,
#   'sk_dm_snr_curve': 124.8081583,
#   'target_class': 0.0},
#  {'mean_integ_prf': 89.4453125,
#   'std_dev_integ_prf': 36.53675559,
#   'ex_kurtosis_integ_prf': 0.895555863,
#   'sk_integ_prf': 3.164132145,
#   'mean_dm_snr_curve': 1.850334448,
#   'std_dev_dm_snr_curve': 15.44632009,
#   'ex_kurtosis_dm_snr_curve': 11.89374235,
#   'sk_dm_snr_curve': 163.945695,
#   'target_class': 0.0},
#  {'mean_integ_prf': 110.0625,
#   'std_dev_integ_prf': 41.78960509,
#   'ex_kurtosis_integ_prf': 0.314973781,
#   'sk_integ_prf': 0.949607938,
#   'mean_dm_snr_curve': 1.611204013,
#   'std_dev_dm_snr_curve': 13.43926664,
#   'ex_kurtosis_dm_snr_curve': 11.80778947,
#   'sk_dm_snr_curve': 170.3712138,
#   'target_class': 0.0},
#  {'mean_integ_prf': 98.5234375,
#   'std_dev_integ_prf': 46.92896308,
#   'ex_kurtosis_integ_prf': 0.29674594600000004,
#   'sk_integ_prf': 0.341512169,
#   'mean_dm_snr_curve': 1.077759197,
#   'std_dev_dm_snr_curve': 12.53415963,
#   'ex_kurtosis_dm_snr_curve': 14.09775951,
#   'sk_dm_snr_curve': 224.31259480000003,
#   'target_class': 0.0},
#  {'mean_integ_prf': 131.4765625,
#   'std_dev_integ_prf': 55.99497255,
#   'ex_kurtosis_integ_prf': 0.064627218,
#   'sk_integ_prf': -0.596634779,
#   'mean_dm_snr_curve': 2.857859532,
#   'std_dev_dm_snr_curve': 18.31021783,
#   'ex_kurtosis_dm_snr_curve': 8.947855846,
#   'sk_dm_snr_curve': 94.30128595,
#   'target_class': 0.0},
#  {'mean_integ_prf': 95.6796875,
#   'std_dev_integ_prf': 40.81665055,
#   'ex_kurtosis_integ_prf': 0.5343751210000001,
#   'sk_integ_prf': 1.4508429369999998,
#   'mean_dm_snr_curve': 3.606187291,
#   'std_dev_dm_snr_curve': 21.24580451,
#   'ex_kurtosis_dm_snr_curve': 7.998484715,
#   'sk_dm_snr_curve': 73.62044003,
#   'target_class': 0.0},
#  {'mean_integ_prf': 109.3359375,
#   'std_dev_integ_prf': 47.86100927,
#   'ex_kurtosis_integ_prf': 0.238169773,
#   'sk_integ_prf': 0.266654812,
#   'mean_dm_snr_curve': 2.219063545,
#   'std_dev_dm_snr_curve': 13.92240217,
#   'ex_kurtosis_dm_snr_curve': 9.655650398999999,
#   'sk_dm_snr_curve': 123.2870333,
#   'target_class': 0.0},
#  {'mean_integ_prf': 112.5390625,
#   'std_dev_integ_prf': 47.18711131,
#   'ex_kurtosis_integ_prf': 0.129595466,
#   'sk_integ_prf': -0.126275519,
#   'mean_dm_snr_curve': 2.31187291,
#   'std_dev_dm_snr_curve': 18.8612845,
#   'ex_kurtosis_dm_snr_curve': 8.90862045,
#   'sk_dm_snr_curve': 84.42433287,
#   'target_class': 0.0},
#  {'mean_integ_prf': 114.828125,
#   'std_dev_integ_prf': 49.34573648,
#   'ex_kurtosis_integ_prf': 0.135934885,
#   'sk_integ_prf': -0.313794504,
#   'mean_dm_snr_curve': 5.418060201,
#   'std_dev_dm_snr_curve': 29.23693674,
#   'ex_kurtosis_dm_snr_curve': 5.904226293,
#   'sk_dm_snr_curve': 35.515654100000006,
#   'target_class': 0.0},
#  {'mean_integ_prf': 126.2421875,
#   'std_dev_integ_prf': 49.27200429999999,
#   'ex_kurtosis_integ_prf': 0.088329184,
#   'sk_integ_prf': -0.147103385,
#   'mean_dm_snr_curve': 1.4615384619999998,
#   'std_dev_dm_snr_curve': 11.59551114,
#   'ex_kurtosis_dm_snr_curve': 12.6384925,
#   'sk_dm_snr_curve': 216.9895575,
#   'target_class': 0.0},
#  {'mean_integ_prf': 117.2421875,
#   'std_dev_integ_prf': 52.80221736,
#   'ex_kurtosis_integ_prf': 0.217252967,
#   'sk_integ_prf': -0.3679260620000001,
#   'mean_dm_snr_curve': 1.358695652,
#   'std_dev_dm_snr_curve': 12.47851396,
#   'ex_kurtosis_dm_snr_curve': 13.0676726,
#   'sk_dm_snr_curve': 204.3573271,
#   'target_class': 0.0},
#  {'mean_integ_prf': 134.8046875,
#   'std_dev_integ_prf': 47.98210255,
#   'ex_kurtosis_integ_prf': -0.218267353,
#   'sk_integ_prf': 0.014367743999999997,
#   'mean_dm_snr_curve': 5.170568562,
#   'std_dev_dm_snr_curve': 27.95880875,
#   'ex_kurtosis_dm_snr_curve': 6.142707674,
#   'sk_dm_snr_curve': 39.65366837,
#   'target_class': 0.0},
#  {'mean_integ_prf': 118.9375,
#   'std_dev_integ_prf': 49.80755935,
#   'ex_kurtosis_integ_prf': 0.394053112,
#   'sk_integ_prf': 0.036605939,
#   'mean_dm_snr_curve': 0.7583612040000001,
#   'std_dev_dm_snr_curve': 9.734999025,
#   'ex_kurtosis_dm_snr_curve': 18.47212344,
#   'sk_dm_snr_curve': 418.4345867,
#   'target_class': 0.0},
#  {'mean_integ_prf': 130.21875,
#   'std_dev_integ_prf': 45.73957147,
#   'ex_kurtosis_integ_prf': -0.00273831,
#   'sk_integ_prf': 0.29734548,
#   'mean_dm_snr_curve': 5.718227425,
#   'std_dev_dm_snr_curve': 25.78250364,
#   'ex_kurtosis_dm_snr_curve': 5.823780289,
#   'sk_dm_snr_curve': 38.07241826,
#   'target_class': 0.0},
#  {'mean_integ_prf': 103.03125,
#   'std_dev_integ_prf': 35.7580711,
#   'ex_kurtosis_integ_prf': 0.403119745,
#   'sk_integ_prf': 1.648295446,
#   'mean_dm_snr_curve': 2.10367893,
#   'std_dev_dm_snr_curve': 18.00824653,
#   'ex_kurtosis_dm_snr_curve': 9.658143197000001,
#   'sk_dm_snr_curve': 100.1517883,
#   'target_class': 0.0},
#  {'mean_integ_prf': 96.3125,
#   'std_dev_integ_prf': 41.47848652,
#   'ex_kurtosis_integ_prf': 0.566614165,
#   'sk_integ_prf': 1.158834437,
#   'mean_dm_snr_curve': 2.574414716,
#   'std_dev_dm_snr_curve': 15.40724695,
#   'ex_kurtosis_dm_snr_curve': 9.061327574,
#   'sk_dm_snr_curve': 106.2126468,
#   'target_class': 0.0},
#  {'mean_integ_prf': 110.2890625,
#   'std_dev_integ_prf': 48.79103279,
#   'ex_kurtosis_integ_prf': 0.207246515,
#   'sk_integ_prf': -0.188130235,
#   'mean_dm_snr_curve': 1.130434783,
#   'std_dev_dm_snr_curve': 12.89265081,
#   'ex_kurtosis_dm_snr_curve': 14.04214862,
#   'sk_dm_snr_curve': 223.5576777,
#   'target_class': 0.0},
#  {'mean_integ_prf': 118.140625,
#   'std_dev_integ_prf': 58.5621644,
#   'ex_kurtosis_integ_prf': 0.148266465,
#   'sk_integ_prf': -0.804809152,
#   'mean_dm_snr_curve': 2.054347826,
#   'std_dev_dm_snr_curve': 14.64957073,
#   'ex_kurtosis_dm_snr_curve': 10.69513835,
#   'sk_dm_snr_curve': 145.13370690000005,
#   'target_class': 0.0},
#  {'mean_integ_prf': 69.2109375,
#   'std_dev_integ_prf': 35.25723604,
#   'ex_kurtosis_integ_prf': 1.093096134,
#   'sk_integ_prf': 4.435121802,
#   'mean_dm_snr_curve': 2.345317726,
#   'std_dev_dm_snr_curve': 20.20025961,
#   'ex_kurtosis_dm_snr_curve': 9.389613296,
#   'sk_dm_snr_curve': 91.75081705,
#   'target_class': 1.0},
#  {'mean_integ_prf': 120.03125,
#   'std_dev_integ_prf': 55.15148705,
#   'ex_kurtosis_integ_prf': -0.121200047,
#   'sk_integ_prf': -0.361874096,
#   'mean_dm_snr_curve': 3.170568562,
#   'std_dev_dm_snr_curve': 18.3006571,
#   'ex_kurtosis_dm_snr_curve': 7.026262799,
#   'sk_dm_snr_curve': 58.5223561,
#   'target_class': 0.0},
#  {'mean_integ_prf': 119.984375,
#   'std_dev_integ_prf': 45.06384089,
#   'ex_kurtosis_integ_prf': 0.182795197,
#   'sk_integ_prf': 0.128979534,
#   'mean_dm_snr_curve': 2.359531773,
#   'std_dev_dm_snr_curve': 14.67118423,
#   'ex_kurtosis_dm_snr_curve': 9.341504038,
#   'sk_dm_snr_curve': 112.9758503,
#   'target_class': 0.0},
#  {'mean_integ_prf': 126.5546875,
#   'std_dev_integ_prf': 45.01333285,
#   'ex_kurtosis_integ_prf': 0.380317761,
#   'sk_integ_prf': 0.308553175,
#   'mean_dm_snr_curve': 4.983277592,
#   'std_dev_dm_snr_curve': 28.88093517,
#   'ex_kurtosis_dm_snr_curve': 5.938614332999999,
#   'sk_dm_snr_curve': 34.91794317,
#   'target_class': 1.0},
#  {'mean_integ_prf': 126.5546875,
#   'std_dev_integ_prf': 53.52055805,
#   'ex_kurtosis_integ_prf': 0.11648633,
#   'sk_integ_prf': -0.27756295,
#   'mean_dm_snr_curve': 16.89632107,
#   'std_dev_dm_snr_curve': 51.41645124,
#   'ex_kurtosis_dm_snr_curve': 2.9345455460000003,
#   'sk_dm_snr_curve': 7.168551386,
#   'target_class': 0.0},
#  {'mean_integ_prf': 130.2265625,
#   'std_dev_integ_prf': 36.63805545,
#   'ex_kurtosis_integ_prf': -0.108416941,
#   'sk_integ_prf': 1.299277285,
#   'mean_dm_snr_curve': 17.47826087,
#   'std_dev_dm_snr_curve': 46.02987647,
#   'ex_kurtosis_dm_snr_curve': 2.674940606,
#   'sk_dm_snr_curve': 6.396015875,
#   'target_class': 0.0},
#  {'mean_integ_prf': 128.2890625,
#   'std_dev_integ_prf': 55.26514956,
#   'ex_kurtosis_integ_prf': 0.06983484200000001,
#   'sk_integ_prf': -0.443164315,
#   'mean_dm_snr_curve': 1.846989967,
#   'std_dev_dm_snr_curve': 13.24117044,
#   'ex_kurtosis_dm_snr_curve': 11.14255826,
#   'sk_dm_snr_curve': 161.8683904,
#   'target_class': 0.0},
#  {'mean_integ_prf': 139.140625,
#   'std_dev_integ_prf': 43.63838161,
#   'ex_kurtosis_integ_prf': -0.247884078,
#   'sk_integ_prf': 0.098468574,
#   'mean_dm_snr_curve': 4.258361204,
#   'std_dev_dm_snr_curve': 21.3254987,
#   'ex_kurtosis_dm_snr_curve': 6.312534394,
#   'sk_dm_snr_curve': 45.61077912,
#   'target_class': 0.0},
#  {'mean_integ_prf': 128.984375,
#   'std_dev_integ_prf': 52.18102271,
#   'ex_kurtosis_integ_prf': 0.173898954,
#   'sk_integ_prf': -0.429864195,
#   'mean_dm_snr_curve': 1.199832776,
#   'std_dev_dm_snr_curve': 14.82453787,
#   'ex_kurtosis_dm_snr_curve': 13.27809821,
#   'sk_dm_snr_curve': 183.2836143,
#   'target_class': 1.0},
#  {'mean_integ_prf': 95.0078125,
#   'std_dev_integ_prf': 37.6525016,
#   'ex_kurtosis_integ_prf': 0.315869601,
#   'sk_integ_prf': 1.802161665,
#   'mean_dm_snr_curve': 2.9506688960000003,
#   'std_dev_dm_snr_curve': 20.50018536,
#   'ex_kurtosis_dm_snr_curve': 7.809740763,
#   'sk_dm_snr_curve': 66.80014907,
#   'target_class': 0.0},
#  {'mean_integ_prf': 95.2890625,
#   'std_dev_integ_prf': 47.04006808,
#   'ex_kurtosis_integ_prf': 0.411826466,
#   'sk_integ_prf': 0.50311606,
#   'mean_dm_snr_curve': 4.890468227,
#   'std_dev_dm_snr_curve': 23.73887085,
#   'ex_kurtosis_dm_snr_curve': 6.2392359410000005,
#   'sk_dm_snr_curve': 44.17721975,
#   'target_class': 0.0},
#  {'mean_integ_prf': 79.0703125,
#   'std_dev_integ_prf': 43.38385781,
#   'ex_kurtosis_integ_prf': 1.584939782,
#   'sk_integ_prf': 3.885098004,
#   'mean_dm_snr_curve': 34.2173913,
#   'std_dev_dm_snr_curve': 64.41764776,
#   'ex_kurtosis_dm_snr_curve': 1.718283135,
#   'sk_dm_snr_curve': 1.680739323,
#   'target_class': 1.0},
#  {'mean_integ_prf': 131.7734375,
#   'std_dev_integ_prf': 46.85803274,
#   'ex_kurtosis_integ_prf': -0.077511417,
#   'sk_integ_prf': 0.272260622,
#   'mean_dm_snr_curve': 4.265050167,
#   'std_dev_dm_snr_curve': 24.59982358,
#   'ex_kurtosis_dm_snr_curve': 6.467703319,
#   'sk_dm_snr_curve': 44.06410147,
#   'target_class': 0.0},
#  {'mean_integ_prf': 131.9609375,
#   'std_dev_integ_prf': 44.18027741,
#   'ex_kurtosis_integ_prf': 0.192329365,
#   'sk_integ_prf': 0.406702378,
#   'mean_dm_snr_curve': 2.555183946,
#   'std_dev_dm_snr_curve': 17.63987004,
#   'ex_kurtosis_dm_snr_curve': 8.590099462000001,
#   'sk_dm_snr_curve': 87.22027034,
#   'target_class': 0.0},
#  {'mean_integ_prf': 110.7890625,
#   'std_dev_integ_prf': 46.24217034,
#   'ex_kurtosis_integ_prf': 0.154800624,
#   'sk_integ_prf': 0.017427097,
#   'mean_dm_snr_curve': 1.158862876,
#   'std_dev_dm_snr_curve': 10.66178968,
#   'ex_kurtosis_dm_snr_curve': 14.97007423,
#   'sk_dm_snr_curve': 294.0762933000001,
#   'target_class': 0.0},
#  {'mean_integ_prf': 118.8046875,
#   'std_dev_integ_prf': 46.7792453,
#   'ex_kurtosis_integ_prf': 0.282037699,
#   'sk_integ_prf': 0.117742368,
#   'mean_dm_snr_curve': 2.276755853,
#   'std_dev_dm_snr_curve': 14.45704611,
#   'ex_kurtosis_dm_snr_curve': 9.595852078,
#   'sk_dm_snr_curve': 117.9152166,
#   'target_class': 0.0},
#  {'mean_integ_prf': 112.5859375,
#   'std_dev_integ_prf': 37.17537141,
#   'ex_kurtosis_integ_prf': 0.084456105,
#   'sk_integ_prf': 1.379678654,
#   'mean_dm_snr_curve': 14.41220736,
#   'std_dev_dm_snr_curve': 53.97941654,
#   'ex_kurtosis_dm_snr_curve': 3.501441472,
#   'sk_dm_snr_curve': 10.35561243,
#   'target_class': 0.0},
#  {'mean_integ_prf': 132.6640625,
#   'std_dev_integ_prf': 56.39374374,
#   'ex_kurtosis_integ_prf': -0.153433889,
#   'sk_integ_prf': -0.682348594,
#   'mean_dm_snr_curve': 3.18729097,
#   'std_dev_dm_snr_curve': 16.53126274,
#   'ex_kurtosis_dm_snr_curve': 7.62037474,
#   'sk_dm_snr_curve': 75.8111878,
#   'target_class': 0.0},
#  {'mean_integ_prf': 103.0078125,
#   'std_dev_integ_prf': 48.70614952,
#   'ex_kurtosis_integ_prf': 0.238332347,
#   'sk_integ_prf': -0.010529437,
#   'mean_dm_snr_curve': 0.960702341,
#   'std_dev_dm_snr_curve': 10.06239535,
#   'ex_kurtosis_dm_snr_curve': 16.61156827,
#   'sk_dm_snr_curve': 359.8311141000001,
#   'target_class': 0.0},
#  {'mean_integ_prf': 117.2890625,
#   'std_dev_integ_prf': 43.42039274,
#   'ex_kurtosis_integ_prf': 0.078452945,
#   'sk_integ_prf': 0.533665705,
#   'mean_dm_snr_curve': 1.909698997,
#   'std_dev_dm_snr_curve': 15.9215848,
#   'ex_kurtosis_dm_snr_curve': 9.654999002,
#   'sk_dm_snr_curve': 105.3946846,
#   'target_class': 0.0},
#  {'mean_integ_prf': 147.7109375,
#   'std_dev_integ_prf': 55.93301691,
#   'ex_kurtosis_integ_prf': -0.419232164,
#   'sk_integ_prf': -0.493051215,
#   'mean_dm_snr_curve': 2.158862876,
#   'std_dev_dm_snr_curve': 20.61422651,
#   'ex_kurtosis_dm_snr_curve': 9.987386854,
#   'sk_dm_snr_curve': 101.7108027,
#   'target_class': 0.0},
#  {'mean_integ_prf': 115.4609375,
#   'std_dev_integ_prf': 58.18490224,
#   'ex_kurtosis_integ_prf': 0.331789895,
#   'sk_integ_prf': -0.478993736,
#   'mean_dm_snr_curve': 1.5,
#   'std_dev_dm_snr_curve': 13.98837908,
#   'ex_kurtosis_dm_snr_curve': 12.34754736,
#   'sk_dm_snr_curve': 177.3936502,
#   'target_class': 0.0},
#  {'mean_integ_prf': 116.234375,
#   'std_dev_integ_prf': 50.75346115,
#   'ex_kurtosis_integ_prf': 0.342410251,
#   'sk_integ_prf': 0.091198089,
#   'mean_dm_snr_curve': 1.641304348,
#   'std_dev_dm_snr_curve': 11.30998019,
#   'ex_kurtosis_dm_snr_curve': 12.88081641,
#   'sk_dm_snr_curve': 233.89600530000004,
#   'target_class': 0.0},
#  {'mean_integ_prf': 101.6328125,
#   'std_dev_integ_prf': 42.31187612,
#   'ex_kurtosis_integ_prf': 0.667673695,
#   'sk_integ_prf': 1.086732511,
#   'mean_dm_snr_curve': 0.7759197320000001,
#   'std_dev_dm_snr_curve': 10.15580738,
#   'ex_kurtosis_dm_snr_curve': 17.30353586,
#   'sk_dm_snr_curve': 363.8950596,
#   'target_class': 0.0},
#  {'mean_integ_prf': 93.2734375,
#   'std_dev_integ_prf': 34.48770497,
#   'ex_kurtosis_integ_prf': 0.733140039,
#   'sk_integ_prf': 3.1082397210000003,
#   'mean_dm_snr_curve': 2.045150502,
#   'std_dev_dm_snr_curve': 15.17086524,
#   'ex_kurtosis_dm_snr_curve': 9.588639417000001,
#   'sk_dm_snr_curve': 110.0131655,
#   'target_class': 0.0},
#  {'mean_integ_prf': 133.2734375,
#   'std_dev_integ_prf': 48.00857912,
#   'ex_kurtosis_integ_prf': 0.022502268,
#   'sk_integ_prf': -0.123905232,
#   'mean_dm_snr_curve': 2.7408026760000004,
#   'std_dev_dm_snr_curve': 15.08292709,
#   'ex_kurtosis_dm_snr_curve': 8.525313322,
#   'sk_dm_snr_curve': 96.51837908,
#   'target_class': 0.0},
#  {'mean_integ_prf': 139.890625,
#   'std_dev_integ_prf': 38.53675891,
#   'ex_kurtosis_integ_prf': -0.065194501,
#   'sk_integ_prf': 1.335937209,
#   'mean_dm_snr_curve': 1.448996656,
#   'std_dev_dm_snr_curve': 13.93270643,
#   'ex_kurtosis_dm_snr_curve': 12.56388266,
#   'sk_dm_snr_curve': 180.838643,
#   'target_class': 0.0},
#  {'mean_integ_prf': 122.4296875,
#   'std_dev_integ_prf': 52.13948893,
#   'ex_kurtosis_integ_prf': 0.295059112,
#   'sk_integ_prf': 0.013024589,
#   'mean_dm_snr_curve': 15.73996656,
#   'std_dev_dm_snr_curve': 45.046614,
#   'ex_kurtosis_dm_snr_curve': 2.9134880410000004,
#   'sk_dm_snr_curve': 7.745976362,
#   'target_class': 0.0},
#  {'mean_integ_prf': 139.78125,
#   'std_dev_integ_prf': 66.88947711,
#   'ex_kurtosis_integ_prf': -0.280868669,
#   'sk_integ_prf': -1.169241732,
#   'mean_dm_snr_curve': 2.683946488,
#   'std_dev_dm_snr_curve': 21.10137444,
#   'ex_kurtosis_dm_snr_curve': 8.806097052,
#   'sk_dm_snr_curve': 79.95945791,
#   'target_class': 0.0},
#  {'mean_integ_prf': 124.8671875,
#   'std_dev_integ_prf': 49.24529976,
#   'ex_kurtosis_integ_prf': 0.04565894,
#   'sk_integ_prf': -0.16081732199999998,
#   'mean_dm_snr_curve': 2.652173913,
#   'std_dev_dm_snr_curve': 20.42854633,
#   'ex_kurtosis_dm_snr_curve': 9.324247322,
#   'sk_dm_snr_curve': 93.52595981,
#   'target_class': 0.0},
#  {'mean_integ_prf': 121.7265625,
#   'std_dev_integ_prf': 45.79859353,
#   'ex_kurtosis_integ_prf': 0.395521947,
#   'sk_integ_prf': 0.469878693,
#   'mean_dm_snr_curve': 1.376254181,
#   'std_dev_dm_snr_curve': 12.78948034,
#   'ex_kurtosis_dm_snr_curve': 11.96387152,
#   'sk_dm_snr_curve': 176.79078,
#   'target_class': 0.0},
#  {'mean_integ_prf': 96.8984375,
#   'std_dev_integ_prf': 47.00479361,
#   'ex_kurtosis_integ_prf': 0.495675632,
#   'sk_integ_prf': 0.529467661,
#   'mean_dm_snr_curve': 1.039297659,
#   'std_dev_dm_snr_curve': 13.65084047,
#   'ex_kurtosis_dm_snr_curve': 14.87193307,
#   'sk_dm_snr_curve': 233.5906772,
#   'target_class': 0.0},
#  {'mean_integ_prf': 109.6796875,
#   'std_dev_integ_prf': 46.94060968,
#   'ex_kurtosis_integ_prf': 0.300662823,
#   'sk_integ_prf': -0.00894943,
#   'mean_dm_snr_curve': 4.339464883,
#   'std_dev_dm_snr_curve': 24.2772823,
#   'ex_kurtosis_dm_snr_curve': 6.403328919,
#   'sk_dm_snr_curve': 44.19212674,
#   'target_class': 0.0},
#  {'mean_integ_prf': 97.4140625,
#   'std_dev_integ_prf': 43.65749638,
#   'ex_kurtosis_integ_prf': 0.456108308,
#   'sk_integ_prf': 0.823766476,
#   'mean_dm_snr_curve': 1.989966555,
#   'std_dev_dm_snr_curve': 17.79918358,
#   'ex_kurtosis_dm_snr_curve': 10.14478276,
#   'sk_dm_snr_curve': 111.8042062,
#   'target_class': 0.0},
#  {'mean_integ_prf': 128.890625,
#   'std_dev_integ_prf': 52.09595029,
#   'ex_kurtosis_integ_prf': 0.090649498,
#   'sk_integ_prf': -0.147498257,
#   'mean_dm_snr_curve': 1.372073579,
#   'std_dev_dm_snr_curve': 10.58337764,
#   'ex_kurtosis_dm_snr_curve': 14.40569903,
#   'sk_dm_snr_curve': 291.6838658000001,
#   'target_class': 0.0},
#  {'mean_integ_prf': 107.625,
#   'std_dev_integ_prf': 37.77668759,
#   'ex_kurtosis_integ_prf': 0.436000412,
#   'sk_integ_prf': 1.73132566,
#   'mean_dm_snr_curve': 2.173913043,
#   'std_dev_dm_snr_curve': 14.6358195,
#   'ex_kurtosis_dm_snr_curve': 9.407370847000001,
#   'sk_dm_snr_curve': 111.7509017,
#   'target_class': 0.0},
#  {'mean_integ_prf': 76.5703125,
#   'std_dev_integ_prf': 39.10596254,
#   'ex_kurtosis_integ_prf': 0.8073307890000001,
#   'sk_integ_prf': 2.1748188180000003,
#   'mean_dm_snr_curve': 1.868729097,
#   'std_dev_dm_snr_curve': 18.19906624,
#   'ex_kurtosis_dm_snr_curve': 10.55616694,
#   'sk_dm_snr_curve': 115.6891888,
#   'target_class': 0.0},
#  {'mean_integ_prf': 140.4296875,
#   'std_dev_integ_prf': 47.06406598,
#   'ex_kurtosis_integ_prf': -0.048904984000000006,
#   'sk_integ_prf': 0.499820383,
#   'mean_dm_snr_curve': 0.543478261,
#   'std_dev_dm_snr_curve': 10.08130572,
#   'ex_kurtosis_dm_snr_curve': 22.57353773,
#   'sk_dm_snr_curve': 532.2214245,
#   'target_class': 0.0},
#  {'mean_integ_prf': 101.2890625,
#   'std_dev_integ_prf': 39.74727828,
#   'ex_kurtosis_integ_prf': 0.668382061,
#   'sk_integ_prf': 1.695142493,
#   'mean_dm_snr_curve': 2.071070234,
#   'std_dev_dm_snr_curve': 16.33647454,
#   'ex_kurtosis_dm_snr_curve': 9.321298743,
#   'sk_dm_snr_curve': 99.14919639,
#   'target_class': 0.0},
#  {'mean_integ_prf': 138.8046875,
#   'std_dev_integ_prf': 47.95620701,
#   'ex_kurtosis_integ_prf': 0.052261198,
#   'sk_integ_prf': 0.144511739,
#   'mean_dm_snr_curve': 4.719063545,
#   'std_dev_dm_snr_curve': 26.45643237,
#   'ex_kurtosis_dm_snr_curve': 6.387733991,
#   'sk_dm_snr_curve': 43.34347306,
#   'target_class': 0.0},
#  {'mean_integ_prf': 121.8671875,
#   'std_dev_integ_prf': 50.26156134,
#   'ex_kurtosis_integ_prf': 0.101663708,
#   'sk_integ_prf': -0.08782148,
#   'mean_dm_snr_curve': 8.392976589,
#   'std_dev_dm_snr_curve': 35.66212334,
#   'ex_kurtosis_dm_snr_curve': 4.36482761,
#   'sk_dm_snr_curve': 18.46770379,
#   'target_class': 0.0},
#  {'mean_integ_prf': 86.5625,
#   'std_dev_integ_prf': 33.18290929,
#   'ex_kurtosis_integ_prf': 0.803473542,
#   'sk_integ_prf': 4.0182796760000015,
#   'mean_dm_snr_curve': 2.364548495,
#   'std_dev_dm_snr_curve': 16.36894484,
#   'ex_kurtosis_dm_snr_curve': 8.557061818,
#   'sk_dm_snr_curve': 86.85427143,
#   'target_class': 0.0},
#  {'mean_integ_prf': 60.296875,
#   'std_dev_integ_prf': 46.44508844,
#   'ex_kurtosis_integ_prf': 2.07886629,
#   'sk_integ_prf': 4.677566913,
#   'mean_dm_snr_curve': 99.69816054,
#   'std_dev_dm_snr_curve': 79.81386182,
#   'ex_kurtosis_dm_snr_curve': 0.078518481,
#   'sk_dm_snr_curve': -1.173577082,
#   'target_class': 1.0},
#  {'mean_integ_prf': 120.7265625,
#   'std_dev_integ_prf': 36.47317397,
#   'ex_kurtosis_integ_prf': 0.110689295,
#   'sk_integ_prf': 1.223632929,
#   'mean_dm_snr_curve': 3.061036789,
#   'std_dev_dm_snr_curve': 17.80342646,
#   'ex_kurtosis_dm_snr_curve': 8.168925188,
#   'sk_dm_snr_curve': 82.29515076,
#   'target_class': 0.0},
#  {'mean_integ_prf': 109.4453125,
#   'std_dev_integ_prf': 45.58436694,
#   'ex_kurtosis_integ_prf': 0.258934957,
#   'sk_integ_prf': 0.324588769,
#   'mean_dm_snr_curve': 1.595317726,
#   'std_dev_dm_snr_curve': 11.59828344,
#   'ex_kurtosis_dm_snr_curve': 12.502274,
#   'sk_dm_snr_curve': 215.8325409,
#   'target_class': 0.0},
#  {'mean_integ_prf': 119.8046875,
#   'std_dev_integ_prf': 44.39208449,
#   'ex_kurtosis_integ_prf': 0.20889498,
#   'sk_integ_prf': 0.820881228,
#   'mean_dm_snr_curve': 3.0117056860000004,
#   'std_dev_dm_snr_curve': 24.44781207,
#   'ex_kurtosis_dm_snr_curve': 8.05999557,
#   'sk_dm_snr_curve': 63.59336881,
#   'target_class': 0.0},
#  {'mean_integ_prf': 123.7109375,
#   'std_dev_integ_prf': 49.39717103,
#   'ex_kurtosis_integ_prf': 0.028392948,
#   'sk_integ_prf': -0.274334322,
#   'mean_dm_snr_curve': 4.110367893,
#   'std_dev_dm_snr_curve': 24.02032708,
#   'ex_kurtosis_dm_snr_curve': 7.044723014,
#   'sk_dm_snr_curve': 54.05241061,
#   'target_class': 0.0},
#  {'mean_integ_prf': 121.1015625,
#   'std_dev_integ_prf': 51.76944681,
#   'ex_kurtosis_integ_prf': -0.032284824,
#   'sk_integ_prf': -0.33796855,
#   'mean_dm_snr_curve': 1.35451505,
#   'std_dev_dm_snr_curve': 10.4356479,
#   'ex_kurtosis_dm_snr_curve': 14.92496544,
#   'sk_dm_snr_curve': 308.5622582,
#   'target_class': 0.0},
#  {'mean_integ_prf': 123.828125,
#   'std_dev_integ_prf': 49.61289358,
#   'ex_kurtosis_integ_prf': 0.225556765,
#   'sk_integ_prf': -0.067658364,
#   'mean_dm_snr_curve': 1.367056856,
#   'std_dev_dm_snr_curve': 14.85064614,
#   'ex_kurtosis_dm_snr_curve': 13.47996527,
#   'sk_dm_snr_curve': 198.7125278,
#   'target_class': 0.0},
#  {'mean_integ_prf': 108.9140625,
#   'std_dev_integ_prf': 51.42379485,
#   'ex_kurtosis_integ_prf': 0.108284036,
#   'sk_integ_prf': -0.212734338,
#   'mean_dm_snr_curve': 3.14548495,
#   'std_dev_dm_snr_curve': 16.51771841,
#   'ex_kurtosis_dm_snr_curve': 7.933097984,
#   'sk_dm_snr_curve': 83.85962351,
#   'target_class': 0.0},
#  {'mean_integ_prf': 128.6328125,
#   'std_dev_integ_prf': 43.82027768,
#   'ex_kurtosis_integ_prf': 0.173075914,
#   'sk_integ_prf': 0.17595750300000002,
#   'mean_dm_snr_curve': 1.994983278,
#   'std_dev_dm_snr_curve': 15.98672029,
#   'ex_kurtosis_dm_snr_curve': 9.534335567000001,
#   'sk_dm_snr_curve': 104.7606871,
#   'target_class': 0.0},
#  {'mean_integ_prf': 61.671875,
#   'std_dev_integ_prf': 36.37545304,
#   'ex_kurtosis_integ_prf': 2.265220701,
#   'sk_integ_prf': 8.709980861,
#   'mean_dm_snr_curve': 5.593645485,
#   'std_dev_dm_snr_curve': 29.62396029,
#   'ex_kurtosis_dm_snr_curve': 6.0722159310000015,
#   'sk_dm_snr_curve': 38.23599074,
#   'target_class': 1.0},
#  {'mean_integ_prf': 128.2578125,
#   'std_dev_integ_prf': 41.2530768,
#   'ex_kurtosis_integ_prf': -0.225800599,
#   'sk_integ_prf': 0.485866888,
#   'mean_dm_snr_curve': 23.81688963,
#   'std_dev_dm_snr_curve': 62.88881,
#   'ex_kurtosis_dm_snr_curve': 2.384960386,
#   'sk_dm_snr_curve': 4.001859336,
#   'target_class': 0.0},
#  {'mean_integ_prf': 142.2890625,
#   'std_dev_integ_prf': 49.05611461,
#   'ex_kurtosis_integ_prf': -0.111128087,
#   'sk_integ_prf': -0.096114076,
#   'mean_dm_snr_curve': 15.65133779,
#   'std_dev_dm_snr_curve': 49.30315077,
#   'ex_kurtosis_dm_snr_curve': 3.073278401,
#   'sk_dm_snr_curve': 8.20273753,
#   'target_class': 0.0},
#  {'mean_integ_prf': 141.1953125,
#   'std_dev_integ_prf': 41.90652891,
#   'ex_kurtosis_integ_prf': 0.042272873,
#   'sk_integ_prf': 0.392180358,
#   'mean_dm_snr_curve': 2.5484949830000003,
#   'std_dev_dm_snr_curve': 16.65055432,
#   'ex_kurtosis_dm_snr_curve': 8.97622333,
#   'sk_dm_snr_curve': 95.09153792,
#   'target_class': 0.0},
#  {'mean_integ_prf': 110.0234375,
#   'std_dev_integ_prf': 41.40830699,
#   'ex_kurtosis_integ_prf': 0.340431133,
#   'sk_integ_prf': 0.6033766079999999,
#   'mean_dm_snr_curve': 0.718227425,
#   'std_dev_dm_snr_curve': 9.763681022,
#   'ex_kurtosis_dm_snr_curve': 21.50492262,
#   'sk_dm_snr_curve': 508.6851987,
#   'target_class': 0.0},
#  {'mean_integ_prf': 133.0703125,
#   'std_dev_integ_prf': 56.08993665,
#   'ex_kurtosis_integ_prf': -0.31269993,
#   'sk_integ_prf': -0.4056695970000001,
#   'mean_dm_snr_curve': 19.85033445,
#   'std_dev_dm_snr_curve': 54.98739754,
#   'ex_kurtosis_dm_snr_curve': 2.633799311,
#   'sk_dm_snr_curve': 5.41962489,
#   'target_class': 0.0},
#  {'mean_integ_prf': 100.9765625,
#   'std_dev_integ_prf': 43.2256913,
#   'ex_kurtosis_integ_prf': 0.302312855,
#   'sk_integ_prf': 0.515795646,
#   'mean_dm_snr_curve': 6.6596989970000005,
#   'std_dev_dm_snr_curve': 32.01672454,
#   'ex_kurtosis_dm_snr_curve': 5.384701738,
#   'sk_dm_snr_curve': 30.19260845,
#   'target_class': 0.0},
#  {'mean_integ_prf': 130.3046875,
#   'std_dev_integ_prf': 53.43622931,
#   'ex_kurtosis_integ_prf': -0.191159541,
#   'sk_integ_prf': -0.5655648839999999,
#   'mean_dm_snr_curve': 2.726588629,
#   'std_dev_dm_snr_curve': 19.95319763,
#   'ex_kurtosis_dm_snr_curve': 8.065141302999999,
#   'sk_dm_snr_curve': 69.60499262,
#   'target_class': 0.0},
#  {'mean_integ_prf': 115.0859375,
#   'std_dev_integ_prf': 50.8593384,
#   'ex_kurtosis_integ_prf': 0.129922059,
#   'sk_integ_prf': -0.15021642,
#   'mean_dm_snr_curve': 1.845317726,
#   'std_dev_dm_snr_curve': 17.26476838,
#   'ex_kurtosis_dm_snr_curve': 10.45845959,
#   'sk_dm_snr_curve': 117.2032047,
#   'target_class': 0.0},
#  {'mean_integ_prf': 127.8046875,
#   'std_dev_integ_prf': 53.55838791,
#   'ex_kurtosis_integ_prf': 0.119318565,
#   'sk_integ_prf': -0.360250434,
#   'mean_dm_snr_curve': 1.923076923,
#   'std_dev_dm_snr_curve': 12.25580618,
#   'ex_kurtosis_dm_snr_curve': 10.79403768,
#   'sk_dm_snr_curve': 170.1499551,
#   'target_class': 0.0},
#  {'mean_integ_prf': 114.5859375,
#   'std_dev_integ_prf': 59.537085,
#   'ex_kurtosis_integ_prf': 0.34622081600000004,
#   'sk_integ_prf': -0.7054727279999999,
#   'mean_dm_snr_curve': 3.777591973,
#   'std_dev_dm_snr_curve': 26.55616311,
#   'ex_kurtosis_dm_snr_curve': 7.74997845,
#   'sk_dm_snr_curve': 60.45059899,
#   'target_class': 1.0},
#  {'mean_integ_prf': 108.90625,
#   'std_dev_integ_prf': 48.72650676,
#   'ex_kurtosis_integ_prf': -0.005444106999999999,
#   'sk_integ_prf': 0.279033174,
#   'mean_dm_snr_curve': 103.0936455,
#   'std_dev_dm_snr_curve': 93.2691448,
#   'ex_kurtosis_dm_snr_curve': -0.169285978,
#   'sk_dm_snr_curve': -1.903601932,
#   'target_class': 0.0},
#  {'mean_integ_prf': 114.5546875,
#   'std_dev_integ_prf': 50.90490653,
#   'ex_kurtosis_integ_prf': 0.269434624,
#   'sk_integ_prf': -0.261158229,
#   'mean_dm_snr_curve': 2.672240803,
#   'std_dev_dm_snr_curve': 17.73795504,
#   'ex_kurtosis_dm_snr_curve': 8.356151236,
#   'sk_dm_snr_curve': 81.24054453,
#   'target_class': 0.0},
#  {'mean_integ_prf': 127.921875,
#   'std_dev_integ_prf': 55.65246645,
#   'ex_kurtosis_integ_prf': -0.157853185,
#   'sk_integ_prf': -0.698161438,
#   'mean_dm_snr_curve': 1.986622074,
#   'std_dev_dm_snr_curve': 16.58372358,
#   'ex_kurtosis_dm_snr_curve': 10.60320028,
#   'sk_dm_snr_curve': 124.89077659999998,
#   'target_class': 0.0},
#  {'mean_integ_prf': 144.0859375,
#   'std_dev_integ_prf': 49.2923402,
#   'ex_kurtosis_integ_prf': -0.065190361,
#   'sk_integ_prf': -0.180708288,
#   'mean_dm_snr_curve': 2.679765886,
#   'std_dev_dm_snr_curve': 16.47396726,
#   'ex_kurtosis_dm_snr_curve': 7.831107155,
#   'sk_dm_snr_curve': 75.93746199,
#   'target_class': 0.0},
#  {'mean_integ_prf': 114.1640625,
#   'std_dev_integ_prf': 50.97407082,
#   'ex_kurtosis_integ_prf': 0.00336734,
#   'sk_integ_prf': -0.312988521,
#   'mean_dm_snr_curve': 1.214882943,
#   'std_dev_dm_snr_curve': 12.03297362,
#   'ex_kurtosis_dm_snr_curve': 13.37219915,
#   'sk_dm_snr_curve': 218.3875382,
#   'target_class': 0.0},
#  {'mean_integ_prf': 115.890625,
#   'std_dev_integ_prf': 50.11459281,
#   'ex_kurtosis_integ_prf': 0.323824914,
#   'sk_integ_prf': 0.130624868,
#   'mean_dm_snr_curve': 1.903846154,
#   'std_dev_dm_snr_curve': 12.74216732,
#   'ex_kurtosis_dm_snr_curve': 11.41807824,
#   'sk_dm_snr_curve': 170.6095746,
#   'target_class': 0.0},
#  {'mean_integ_prf': 130.78125,
#   'std_dev_integ_prf': 47.61613065,
#   'ex_kurtosis_integ_prf': 0.001044529,
#   'sk_integ_prf': -0.114471999,
#   'mean_dm_snr_curve': 1.898829431,
#   'std_dev_dm_snr_curve': 12.27727182,
#   'ex_kurtosis_dm_snr_curve': 11.42853253,
#   'sk_dm_snr_curve': 180.1409052,
#   'target_class': 0.0},
#  {'mean_integ_prf': 125.3671875,
#   'std_dev_integ_prf': 49.26583995,
#   'ex_kurtosis_integ_prf': -0.032366243,
#   'sk_integ_prf': -0.119016489,
#   'mean_dm_snr_curve': 2.556856187,
#   'std_dev_dm_snr_curve': 14.59168722,
#   'ex_kurtosis_dm_snr_curve': 8.869674605,
#   'sk_dm_snr_curve': 105.5824476,
#   'target_class': 0.0},
#  {'mean_integ_prf': 131.40625,
#   'std_dev_integ_prf': 52.96924779,
#   'ex_kurtosis_integ_prf': 0.067051822,
#   'sk_integ_prf': -0.366704922,
#   'mean_dm_snr_curve': 175.57859530000005,
#   'std_dev_dm_snr_curve': 88.16542302,
#   'ex_kurtosis_dm_snr_curve': -1.186196012,
#   'sk_dm_snr_curve': -0.224693974,
#   'target_class': 0.0},
#  {'mean_integ_prf': 109.203125,
#   'std_dev_integ_prf': 51.11298138,
#   'ex_kurtosis_integ_prf': 0.220206067,
#   'sk_integ_prf': 0.055751965,
#   'mean_dm_snr_curve': 2.070234114,
#   'std_dev_dm_snr_curve': 14.8237725,
#   'ex_kurtosis_dm_snr_curve': 10.25307236,
#   'sk_dm_snr_curve': 129.8853999,
#   'target_class': 0.0},
#  {'mean_integ_prf': 9.7421875,
#   'std_dev_integ_prf': 30.26219953,
#   'ex_kurtosis_integ_prf': 7.088609517999999,
#   'sk_integ_prf': 50.95424904,
#   'mean_dm_snr_curve': 84.11705686,
#   'std_dev_dm_snr_curve': 59.36708836,
#   'ex_kurtosis_dm_snr_curve': 0.901047513,
#   'sk_dm_snr_curve': 0.556315962,
#   'target_class': 1.0},
#  {'mean_integ_prf': 102.875,
#   'std_dev_integ_prf': 43.57590361,
#   'ex_kurtosis_integ_prf': 0.680613625,
#   'sk_integ_prf': 1.188921894,
#   'mean_dm_snr_curve': 4.350334448,
#   'std_dev_dm_snr_curve': 25.98453055,
#   'ex_kurtosis_dm_snr_curve': 6.535209822000001,
#   'sk_dm_snr_curve': 44.61361827,
#   'target_class': 0.0},
#  {'mean_integ_prf': 95.8828125,
#   'std_dev_integ_prf': 48.97346557,
#   'ex_kurtosis_integ_prf': 0.545903436,
#   'sk_integ_prf': 0.7309570129999999,
#   'mean_dm_snr_curve': 1.739130435,
#   'std_dev_dm_snr_curve': 12.56782963,
#   'ex_kurtosis_dm_snr_curve': 11.53867869,
#   'sk_dm_snr_curve': 174.4031315,
#   'target_class': 0.0},
#  {'mean_integ_prf': 130.1015625,
#   'std_dev_integ_prf': 49.1820343,
#   'ex_kurtosis_integ_prf': 0.101108121,
#   'sk_integ_prf': 0.011775402,
#   'mean_dm_snr_curve': 2.397993311,
#   'std_dev_dm_snr_curve': 14.62675411,
#   'ex_kurtosis_dm_snr_curve': 8.738222472,
#   'sk_dm_snr_curve': 101.1514239,
#   'target_class': 0.0},
#  {'mean_integ_prf': 135.078125,
#   'std_dev_integ_prf': 43.11713866,
#   'ex_kurtosis_integ_prf': 0.067585331,
#   'sk_integ_prf': 0.061427247,
#   'mean_dm_snr_curve': 2.080267559,
#   'std_dev_dm_snr_curve': 13.33960502,
#   'ex_kurtosis_dm_snr_curve': 9.979061296,
#   'sk_dm_snr_curve': 135.78535569999997,
#   'target_class': 0.0},
#  {'mean_integ_prf': 133.4765625,
#   'std_dev_integ_prf': 48.63222389,
#   'ex_kurtosis_integ_prf': -0.232863347,
#   'sk_integ_prf': -0.102144782,
#   'mean_dm_snr_curve': 3.754180602,
#   'std_dev_dm_snr_curve': 24.89724248,
#   'ex_kurtosis_dm_snr_curve': 7.211629975,
#   'sk_dm_snr_curve': 54.14399937,
#   'target_class': 0.0},
#  {'mean_integ_prf': 122.7265625,
#   'std_dev_integ_prf': 48.97348052,
#   'ex_kurtosis_integ_prf': -0.018332218,
#   'sk_integ_prf': 0.002608603,
#   'mean_dm_snr_curve': 10.40217391,
#   'std_dev_dm_snr_curve': 39.75924152,
#   'ex_kurtosis_dm_snr_curve': 4.020460464,
#   'sk_dm_snr_curve': 15.51974367,
#   'target_class': 0.0},
#  {'mean_integ_prf': 84.3359375,
#   'std_dev_integ_prf': 42.10260483,
#   'ex_kurtosis_integ_prf': 0.859224743,
#   'sk_integ_prf': 1.982141691,
#   'mean_dm_snr_curve': 11.53344482,
#   'std_dev_dm_snr_curve': 43.87085469,
#   'ex_kurtosis_dm_snr_curve': 3.969981663,
#   'sk_dm_snr_curve': 14.9778981,
#   'target_class': 1.0},
#  {'mean_integ_prf': 97.8125,
#   'std_dev_integ_prf': 38.59540735,
#   'ex_kurtosis_integ_prf': 0.441153552,
#   'sk_integ_prf': 1.814031082,
#   'mean_dm_snr_curve': 3.320234114,
#   'std_dev_dm_snr_curve': 21.14427962,
#   'ex_kurtosis_dm_snr_curve': 7.860980927000001,
#   'sk_dm_snr_curve': 69.13862025,
#   'target_class': 0.0},
#  {'mean_integ_prf': 115.078125,
#   'std_dev_integ_prf': 55.9505375,
#   'ex_kurtosis_integ_prf': 0.228534597,
#   'sk_integ_prf': -0.465533862,
#   'mean_dm_snr_curve': 2.299331104,
#   'std_dev_dm_snr_curve': 20.36044019,
#   'ex_kurtosis_dm_snr_curve': 9.781064313,
#   'sk_dm_snr_curve': 99.77506737,
#   'target_class': 0.0},
#  {'mean_integ_prf': 114.203125,
#   'std_dev_integ_prf': 49.44589205,
#   'ex_kurtosis_integ_prf': 0.008293758,
#   'sk_integ_prf': -0.141872468,
#   'mean_dm_snr_curve': 2.486622074,
#   'std_dev_dm_snr_curve': 15.34025422,
#   'ex_kurtosis_dm_snr_curve': 9.228698148,
#   'sk_dm_snr_curve': 109.2857195,
#   'target_class': 0.0},
#  {'mean_integ_prf': 119.546875,
#   'std_dev_integ_prf': 41.53741901,
#   'ex_kurtosis_integ_prf': 0.13276639099999998,
#   'sk_integ_prf': 1.049137968,
#   'mean_dm_snr_curve': 4.216555184,
#   'std_dev_dm_snr_curve': 25.95131331,
#   'ex_kurtosis_dm_snr_curve': 6.499651157000001,
#   'sk_dm_snr_curve': 43.06361551,
#   'target_class': 0.0},
#  {'mean_integ_prf': 124.2109375,
#   'std_dev_integ_prf': 50.14972151,
#   'ex_kurtosis_integ_prf': 0.112007491,
#   'sk_integ_prf': 0.144351009,
#   'mean_dm_snr_curve': 2.248327759,
#   'std_dev_dm_snr_curve': 13.78669463,
#   'ex_kurtosis_dm_snr_curve': 9.902157411000001,
#   'sk_dm_snr_curve': 130.21232709999998,
#   'target_class': 0.0},
#  {'mean_integ_prf': 95.9296875,
#   'std_dev_integ_prf': 49.88693209,
#   'ex_kurtosis_integ_prf': 0.273500764,
#   'sk_integ_prf': -0.321400647,
#   'mean_dm_snr_curve': 27.05769231,
#   'std_dev_dm_snr_curve': 69.24734531,
#   'ex_kurtosis_dm_snr_curve': 2.181897698,
#   'sk_dm_snr_curve': 2.8031899260000004,
#   'target_class': 0.0},
#  {'mean_integ_prf': 66.4921875,
#   'std_dev_integ_prf': 33.84292672,
#   'ex_kurtosis_integ_prf': 2.542730429,
#   'sk_integ_prf': 10.99489305,
#   'mean_dm_snr_curve': 7.834448161,
#   'std_dev_dm_snr_curve': 33.66162057,
#   'ex_kurtosis_dm_snr_curve': 5.091572704,
#   'sk_dm_snr_curve': 26.9122828,
#   'target_class': 1.0},
#  {'mean_integ_prf': 85.796875,
#   'std_dev_integ_prf': 39.86625284,
#   'ex_kurtosis_integ_prf': 0.580524256,
#   'sk_integ_prf': 1.452630674,
#   'mean_dm_snr_curve': 1.6212374580000002,
#   'std_dev_dm_snr_curve': 13.5821365,
#   'ex_kurtosis_dm_snr_curve': 11.40062521,
#   'sk_dm_snr_curve': 156.557796,
#   'target_class': 0.0},
#  {'mean_integ_prf': 136.4453125,
#   'std_dev_integ_prf': 54.86628755,
#   'ex_kurtosis_integ_prf': -0.158676799,
#   'sk_integ_prf': -0.588693512,
#   'mean_dm_snr_curve': 1.852842809,
#   'std_dev_dm_snr_curve': 17.81416755,
#   'ex_kurtosis_dm_snr_curve': 11.05802875,
#   'sk_dm_snr_curve': 127.1433921,
#   'target_class': 0.0},
#  {'mean_integ_prf': 150.25,
#   'std_dev_integ_prf': 53.49328229,
#   'ex_kurtosis_integ_prf': -0.221792439,
#   'sk_integ_prf': -0.309404146,
#   'mean_dm_snr_curve': 2.37541806,
#   'std_dev_dm_snr_curve': 19.15764641,
#   'ex_kurtosis_dm_snr_curve': 10.26621986,
#   'sk_dm_snr_curve': 116.0802966,
#   'target_class': 0.0},
#  {'mean_integ_prf': 143.7109375,
#   'std_dev_integ_prf': 47.21959212,
#   'ex_kurtosis_integ_prf': -0.193884989,
#   'sk_integ_prf': 0.19057915600000006,
#   'mean_dm_snr_curve': 1.191471572,
#   'std_dev_dm_snr_curve': 9.935542807000001,
#   'ex_kurtosis_dm_snr_curve': 16.58796639,
#   'sk_dm_snr_curve': 371.4528926,
#   'target_class': 0.0},
#  {'mean_integ_prf': 122.8125,
#   'std_dev_integ_prf': 39.16327002,
#   'ex_kurtosis_integ_prf': 0.176057944,
#   'sk_integ_prf': 0.782359685,
#   'mean_dm_snr_curve': 3.902173913,
#   'std_dev_dm_snr_curve': 21.11149638,
#   'ex_kurtosis_dm_snr_curve': 6.539225555,
#   'sk_dm_snr_curve': 47.98775704,
#   'target_class': 0.0},
#  {'mean_integ_prf': 122.3359375,
#   'std_dev_integ_prf': 48.86449333,
#   'ex_kurtosis_integ_prf': 0.079585207,
#   'sk_integ_prf': -0.288818016,
#   'mean_dm_snr_curve': 119.0326087,
#   'std_dev_dm_snr_curve': 85.95590633,
#   'ex_kurtosis_dm_snr_curve': -0.613265858,
#   'sk_dm_snr_curve': -1.512690424,
#   'target_class': 0.0},
#  {'mean_integ_prf': 36.46875,
#   'std_dev_integ_prf': 39.27287102,
#   'ex_kurtosis_integ_prf': 3.736450963,
#   'sk_integ_prf': 14.914644699999998,
#   'mean_dm_snr_curve': 111.1229097,
#   'std_dev_dm_snr_curve': 75.71649359,
#   'ex_kurtosis_dm_snr_curve': 0.253562477,
#   'sk_dm_snr_curve': -0.936103674,
#   'target_class': 1.0},
#  {'mean_integ_prf': 111.2109375,
#   'std_dev_integ_prf': 44.75639835,
#   'ex_kurtosis_integ_prf': 0.049738567,
#   'sk_integ_prf': 0.126347724,
#   'mean_dm_snr_curve': 0.887123746,
#   'std_dev_dm_snr_curve': 10.24490091,
#   'ex_kurtosis_dm_snr_curve': 17.11080776,
#   'sk_dm_snr_curve': 358.504497,
#   'target_class': 0.0},
#  {'mean_integ_prf': 133.0859375,
#   'std_dev_integ_prf': 52.80817694,
#   'ex_kurtosis_integ_prf': -0.211585074,
#   'sk_integ_prf': -0.295598653,
#   'mean_dm_snr_curve': 4.035117057,
#   'std_dev_dm_snr_curve': 26.52150205,
#   'ex_kurtosis_dm_snr_curve': 6.923330065,
#   'sk_dm_snr_curve': 48.70415228,
#   'target_class': 0.0},
#  {'mean_integ_prf': 137.75,
#   'std_dev_integ_prf': 51.56731038,
#   'ex_kurtosis_integ_prf': -0.204780636,
#   'sk_integ_prf': -0.122476171,
#   'mean_dm_snr_curve': 111.027592,
#   'std_dev_dm_snr_curve': 77.89253858,
#   'ex_kurtosis_dm_snr_curve': -0.363839554,
#   'sk_dm_snr_curve': -1.348618574,
#   'target_class': 0.0},
#  {'mean_integ_prf': 83.8125,
#   'std_dev_integ_prf': 40.59012927,
#   'ex_kurtosis_integ_prf': 0.611750363,
#   'sk_integ_prf': 1.617375621,
#   'mean_dm_snr_curve': 1.977424749,
#   'std_dev_dm_snr_curve': 14.7608129,
#   'ex_kurtosis_dm_snr_curve': 10.64449998,
#   'sk_dm_snr_curve': 134.24611380000002,
#   'target_class': 0.0},
#  {'mean_integ_prf': 121.84375,
#   'std_dev_integ_prf': 40.74874183,
#   'ex_kurtosis_integ_prf': 0.137360862,
#   'sk_integ_prf': 1.231334637,
# ...
#   'sk_dm_snr_curve': 59.91720072,
#   'target_class': 0.0},
#  {'mean_integ_prf': 105.2421875,
#   'std_dev_integ_prf': 45.73561012,
#   'ex_kurtosis_integ_prf': 0.495771871,
#   'sk_integ_prf': 0.516394798,
#   'mean_dm_snr_curve': 1.5978260869999998,
#   'std_dev_dm_snr_curve': 15.3271884,
#   'ex_kurtosis_dm_snr_curve': 11.72166042,
#   'sk_dm_snr_curve': 153.78827890000005,
#   'target_class': 0.0},
#  {'mean_integ_prf': 128.7421875,
#   'std_dev_integ_prf': 52.27066668,
#   'ex_kurtosis_integ_prf': 0.102810014,
#   'sk_integ_prf': -0.01913178,
#   'mean_dm_snr_curve': 2.394648829,
#   'std_dev_dm_snr_curve': 15.44462884,
#   'ex_kurtosis_dm_snr_curve': 9.22140455,
#   'sk_dm_snr_curve': 107.12427,
#   'target_class': 0.0},
#  {'mean_integ_prf': 75.1015625,
#   'std_dev_integ_prf': 35.11918098,
#   'ex_kurtosis_integ_prf': 2.198113989,
#   'sk_integ_prf': 8.981400545,
#   'mean_dm_snr_curve': 20.89464883,
#   'std_dev_dm_snr_curve': 54.02381432,
#   'ex_kurtosis_dm_snr_curve': 2.580942125,
#   'sk_dm_snr_curve': 5.568507205,
#   'target_class': 1.0},
#  {'mean_integ_prf': 119.7578125,
#   'std_dev_integ_prf': 44.44497056,
#   'ex_kurtosis_integ_prf': 0.300047317,
#   'sk_integ_prf': 0.759060947,
#   'mean_dm_snr_curve': 1.776755853,
#   'std_dev_dm_snr_curve': 16.82681294,
#   'ex_kurtosis_dm_snr_curve': 10.85252257,
#   'sk_dm_snr_curve': 126.0287972,
#   'target_class': 0.0},
#  {'mean_integ_prf': 90.84375,
#   'std_dev_integ_prf': 39.8623486,
#   'ex_kurtosis_integ_prf': 0.553476955,
#   'sk_integ_prf': 1.464542969,
#   'mean_dm_snr_curve': 5.64632107,
#   'std_dev_dm_snr_curve': 25.27341118,
#   'ex_kurtosis_dm_snr_curve': 5.044536586,
#   'sk_dm_snr_curve': 27.44633073,
#   'target_class': 0.0},
#  {'mean_integ_prf': 142.8671875,
#   'std_dev_integ_prf': 51.37505643,
#   'ex_kurtosis_integ_prf': -0.258383799,
#   'sk_integ_prf': -0.118475581,
#   'mean_dm_snr_curve': 7.281772575,
#   'std_dev_dm_snr_curve': 36.39937845,
#   'ex_kurtosis_dm_snr_curve': 5.092862765,
#   'sk_dm_snr_curve': 25.06283316,
#   'target_class': 0.0},
#  {'mean_integ_prf': 111.0078125,
#   'std_dev_integ_prf': 40.56871025,
#   'ex_kurtosis_integ_prf': 0.694214717,
#   'sk_integ_prf': 1.666077082,
#   'mean_dm_snr_curve': 2.827759197,
#   'std_dev_dm_snr_curve': 15.58949024,
#   'ex_kurtosis_dm_snr_curve': 8.04203063,
#   'sk_dm_snr_curve': 84.55699414,
#   'target_class': 0.0},
#  {'mean_integ_prf': 128.390625,
#   'std_dev_integ_prf': 54.43979392,
#   'ex_kurtosis_integ_prf': 0.0032835140000000004,
#   'sk_integ_prf': -0.566704925,
#   'mean_dm_snr_curve': 2.672240803,
#   'std_dev_dm_snr_curve': 16.57060293,
#   'ex_kurtosis_dm_snr_curve': 9.119079332,
#   'sk_dm_snr_curve': 102.3013386,
#   'target_class': 0.0},
#  {'mean_integ_prf': 123.9921875,
#   'std_dev_integ_prf': 44.07247158,
#   'ex_kurtosis_integ_prf': 0.116062247,
#   'sk_integ_prf': 0.029553587000000006,
#   'mean_dm_snr_curve': 1.100334448,
#   'std_dev_dm_snr_curve': 13.75629864,
#   'ex_kurtosis_dm_snr_curve': 15.50767061,
#   'sk_dm_snr_curve': 253.9728219,
#   'target_class': 0.0},
#  {'mean_integ_prf': 85.984375,
#   'std_dev_integ_prf': 34.26618787,
#   'ex_kurtosis_integ_prf': 1.064876034,
#   'sk_integ_prf': 3.50930825,
#   'mean_dm_snr_curve': 2.556020067,
#   'std_dev_dm_snr_curve': 19.03137804,
#   'ex_kurtosis_dm_snr_curve': 8.405033071,
#   'sk_dm_snr_curve': 76.61561098,
#   'target_class': 0.0},
#  {'mean_integ_prf': 119.2421875,
#   'std_dev_integ_prf': 56.07845315,
#   'ex_kurtosis_integ_prf': -0.002208902,
#   'sk_integ_prf': -0.4964843370000001,
#   'mean_dm_snr_curve': 3.156354515,
#   'std_dev_dm_snr_curve': 17.69274556,
#   'ex_kurtosis_dm_snr_curve': 7.748657349,
#   'sk_dm_snr_curve': 76.19545179999999,
#   'target_class': 0.0},
#  {'mean_integ_prf': 124.8125,
#   'std_dev_integ_prf': 48.19179618,
#   'ex_kurtosis_integ_prf': 0.057908897,
#   'sk_integ_prf': 0.014006738,
#   'mean_dm_snr_curve': 0.282608696,
#   'std_dev_dm_snr_curve': 7.565681088,
#   'ex_kurtosis_dm_snr_curve': 32.19858411,
#   'sk_dm_snr_curve': 1072.957979,
#   'target_class': 0.0},
#  {'mean_integ_prf': 102.390625,
#   'std_dev_integ_prf': 46.00954968,
#   'ex_kurtosis_integ_prf': 0.6678229520000001,
#   'sk_integ_prf': 1.14041869,
#   'mean_dm_snr_curve': 3.275919732,
#   'std_dev_dm_snr_curve': 21.20407582,
#   'ex_kurtosis_dm_snr_curve': 7.420476484,
#   'sk_dm_snr_curve': 60.46893597,
#   'target_class': 0.0},
#  {'mean_integ_prf': 100.4921875,
#   'std_dev_integ_prf': 45.3083181,
#   'ex_kurtosis_integ_prf': 0.558835934,
#   'sk_integ_prf': 0.248548967,
#   'mean_dm_snr_curve': 2.45735786,
#   'std_dev_dm_snr_curve': 14.49226599,
#   'ex_kurtosis_dm_snr_curve': 8.740900002,
#   'sk_dm_snr_curve': 103.7965809,
#   'target_class': 0.0},
#  {'mean_integ_prf': 80.8515625,
#   'std_dev_integ_prf': 42.48438865,
#   'ex_kurtosis_integ_prf': 1.7273630290000002,
#   'sk_integ_prf': 4.155505222,
#   'mean_dm_snr_curve': 18.74331104,
#   'std_dev_dm_snr_curve': 52.96375201,
#   'ex_kurtosis_dm_snr_curve': 2.858017126,
#   'sk_dm_snr_curve': 7.055142648,
#   'target_class': 1.0},
#  {'mean_integ_prf': 112.7890625,
#   'std_dev_integ_prf': 48.749143,
#   'ex_kurtosis_integ_prf': 0.174574995,
#   'sk_integ_prf': -0.020146361,
#   'mean_dm_snr_curve': 4.357859532,
#   'std_dev_dm_snr_curve': 28.33942082,
#   'ex_kurtosis_dm_snr_curve': 6.899840384,
#   'sk_dm_snr_curve': 48.05085979,
#   'target_class': 0.0},
#  {'mean_integ_prf': 78.4609375,
#   'std_dev_integ_prf': 37.63224647,
#   'ex_kurtosis_integ_prf': 0.761065718,
#   'sk_integ_prf': 2.51642616,
#   'mean_dm_snr_curve': 2.241638796,
#   'std_dev_dm_snr_curve': 17.16599964,
#   'ex_kurtosis_dm_snr_curve': 8.768598662999999,
#   'sk_dm_snr_curve': 85.69353249999998,
#   'target_class': 0.0},
#  {'mean_integ_prf': 104.5859375,
#   'std_dev_integ_prf': 48.76370438,
#   'ex_kurtosis_integ_prf': 1.217617253,
#   'sk_integ_prf': 1.745402654,
#   'mean_dm_snr_curve': 43.05685619,
#   'std_dev_dm_snr_curve': 68.27689379,
#   'ex_kurtosis_dm_snr_curve': 1.3928483669999998,
#   'sk_dm_snr_curve': 0.56421615,
#   'target_class': 0.0},
#  {'mean_integ_prf': 104.1015625,
#   'std_dev_integ_prf': 36.70146452,
#   'ex_kurtosis_integ_prf': 0.457094823,
#   'sk_integ_prf': 1.599069602,
#   'mean_dm_snr_curve': 2.302675585,
#   'std_dev_dm_snr_curve': 13.97281257,
#   'ex_kurtosis_dm_snr_curve': 9.515597785,
#   'sk_dm_snr_curve': 121.5617523,
#   'target_class': 0.0},
#  {'mean_integ_prf': 92.46875,
#   'std_dev_integ_prf': 37.78949455,
#   'ex_kurtosis_integ_prf': 0.647792775,
#   'sk_integ_prf': 2.055608449,
#   'mean_dm_snr_curve': 0.864548495,
#   'std_dev_dm_snr_curve': 11.98340745,
#   'ex_kurtosis_dm_snr_curve': 15.35544717,
#   'sk_dm_snr_curve': 256.4241567,
#   'target_class': 1.0},
#  {'mean_integ_prf': 80.1484375,
#   'std_dev_integ_prf': 37.09491412,
#   'ex_kurtosis_integ_prf': 0.632101998,
#   'sk_integ_prf': 2.408713702,
#   'mean_dm_snr_curve': 2.423076923,
#   'std_dev_dm_snr_curve': 19.00989716,
#   'ex_kurtosis_dm_snr_curve': 8.965977545,
#   'sk_dm_snr_curve': 87.67688646,
#   'target_class': 0.0},
#  {'mean_integ_prf': 125.546875,
#   'std_dev_integ_prf': 43.04283103,
#   'ex_kurtosis_integ_prf': 0.12323441,
#   'sk_integ_prf': 0.290817897,
#   'mean_dm_snr_curve': 4.964882943,
#   'std_dev_dm_snr_curve': 23.64227063,
#   'ex_kurtosis_dm_snr_curve': 6.285218757000001,
#   'sk_dm_snr_curve': 45.6872032,
#   'target_class': 0.0},
#  {'mean_integ_prf': 87.0703125,
#   'std_dev_integ_prf': 38.08998055,
#   'ex_kurtosis_integ_prf': 0.870472976,
#   'sk_integ_prf': 2.437318676,
#   'mean_dm_snr_curve': 1.464882943,
#   'std_dev_dm_snr_curve': 10.97806894,
#   'ex_kurtosis_dm_snr_curve': 13.90631847,
#   'sk_dm_snr_curve': 263.5604499,
#   'target_class': 0.0},
#  {'mean_integ_prf': 138.4140625,
#   'std_dev_integ_prf': 50.63588268,
#   'ex_kurtosis_integ_prf': -0.406498365,
#   'sk_integ_prf': 0.281909753,
#   'mean_dm_snr_curve': 2.134615385,
#   'std_dev_dm_snr_curve': 13.73961532,
#   'ex_kurtosis_dm_snr_curve': 10.1402777,
#   'sk_dm_snr_curve': 133.9998979,
#   'target_class': 0.0},
#  {'mean_integ_prf': 110.21875,
#   'std_dev_integ_prf': 45.67205408,
#   'ex_kurtosis_integ_prf': 0.53411849,
#   'sk_integ_prf': 0.402540677,
#   'mean_dm_snr_curve': 2.134615385,
#   'std_dev_dm_snr_curve': 17.06375334,
#   'ex_kurtosis_dm_snr_curve': 9.870973132,
#   'sk_dm_snr_curve': 108.6518136,
#   'target_class': 0.0},
#  {'mean_integ_prf': 112.4765625,
#   'std_dev_integ_prf': 58.97112175,
#   'ex_kurtosis_integ_prf': 0.394275867,
#   'sk_integ_prf': -0.6779852340000001,
#   'mean_dm_snr_curve': 3.253344482,
#   'std_dev_dm_snr_curve': 18.03875048,
#   'ex_kurtosis_dm_snr_curve': 8.181099038,
#   'sk_dm_snr_curve': 82.64455113,
#   'target_class': 0.0},
#  {'mean_integ_prf': 102.6640625,
#   'std_dev_integ_prf': 48.71541679,
#   'ex_kurtosis_integ_prf': 0.390332676,
#   'sk_integ_prf': 0.203373236,
#   'mean_dm_snr_curve': 1.725752508,
#   'std_dev_dm_snr_curve': 15.55726413,
#   'ex_kurtosis_dm_snr_curve': 11.07803688,
#   'sk_dm_snr_curve': 137.4626716,
#   'target_class': 0.0},
#  {'mean_integ_prf': 92.6953125,
#   'std_dev_integ_prf': 40.76754963,
#   'ex_kurtosis_integ_prf': 0.292746538,
#   'sk_integ_prf': 1.112674151,
#   'mean_dm_snr_curve': 0.998327759,
#   'std_dev_dm_snr_curve': 12.76426334,
#   'ex_kurtosis_dm_snr_curve': 14.97948287,
#   'sk_dm_snr_curve': 247.9089992,
#   'target_class': 0.0},
#  {'mean_integ_prf': 137.078125,
#   'std_dev_integ_prf': 42.91991259,
#   'ex_kurtosis_integ_prf': -0.180456387,
#   'sk_integ_prf': 0.121366484,
#   'mean_dm_snr_curve': 37.15802676,
#   'std_dev_dm_snr_curve': 74.75640001,
#   'ex_kurtosis_dm_snr_curve': 1.623415939,
#   'sk_dm_snr_curve': 0.845355053,
#   'target_class': 0.0},
#  {'mean_integ_prf': 131.6484375,
#   'std_dev_integ_prf': 50.25491112,
#   'ex_kurtosis_integ_prf': 0.009662008,
#   'sk_integ_prf': 0.08527672300000001,
#   'mean_dm_snr_curve': 0.213210702,
#   'std_dev_dm_snr_curve': 7.370432165,
#   'ex_kurtosis_dm_snr_curve': 34.53984419,
#   'sk_dm_snr_curve': 1191.0008369999996,
#   'target_class': 0.0},
#  {'mean_integ_prf': 110.265625,
#   'std_dev_integ_prf': 42.39610175,
#   'ex_kurtosis_integ_prf': 0.381322228,
#   'sk_integ_prf': 0.969407829,
#   'mean_dm_snr_curve': 2.362040134,
#   'std_dev_dm_snr_curve': 14.73421826,
#   'ex_kurtosis_dm_snr_curve': 9.861679956,
#   'sk_dm_snr_curve': 122.1684104,
#   'target_class': 0.0},
#  {'mean_integ_prf': 113.125,
#   'std_dev_integ_prf': 42.5422584,
#   'ex_kurtosis_integ_prf': 0.201745788,
#   'sk_integ_prf': 0.483429766,
#   'mean_dm_snr_curve': 2.27090301,
#   'std_dev_dm_snr_curve': 15.59452318,
#   'ex_kurtosis_dm_snr_curve': 9.663599782999999,
#   'sk_dm_snr_curve': 111.0802507,
#   'target_class': 0.0},
#  {'mean_integ_prf': 163.0078125,
#   'std_dev_integ_prf': 41.52098417,
#   'ex_kurtosis_integ_prf': -0.317773136,
#   'sk_integ_prf': 0.919535283,
#   'mean_dm_snr_curve': 6.090301003,
#   'std_dev_dm_snr_curve': 29.42810875,
#   'ex_kurtosis_dm_snr_curve': 5.352027589,
#   'sk_dm_snr_curve': 30.06826881,
#   'target_class': 0.0},
#  {'mean_integ_prf': 118.765625,
#   'std_dev_integ_prf': 46.383504,
#   'ex_kurtosis_integ_prf': 0.124385505,
#   'sk_integ_prf': 0.27872968,
#   'mean_dm_snr_curve': 2.753344482,
#   'std_dev_dm_snr_curve': 24.47167902,
#   'ex_kurtosis_dm_snr_curve': 8.807768459,
#   'sk_dm_snr_curve': 75.89038853,
#   'target_class': 0.0},
#  {'mean_integ_prf': 95.765625,
#   'std_dev_integ_prf': 37.21694934,
#   'ex_kurtosis_integ_prf': 0.489793899,
#   'sk_integ_prf': 1.494613764,
#   'mean_dm_snr_curve': 4.908026756,
#   'std_dev_dm_snr_curve': 24.03915916,
#   'ex_kurtosis_dm_snr_curve': 6.0870603810000015,
#   'sk_dm_snr_curve': 41.49961829,
#   'target_class': 0.0},
#  {'mean_integ_prf': 130.8046875,
#   'std_dev_integ_prf': 45.93610688,
#   'ex_kurtosis_integ_prf': -0.02122311,
#   'sk_integ_prf': -0.118586736,
#   'mean_dm_snr_curve': 3.893812709,
#   'std_dev_dm_snr_curve': 19.92241461,
#   'ex_kurtosis_dm_snr_curve': 6.895456365,
#   'sk_dm_snr_curve': 55.96095373,
#   'target_class': 0.0},
#  {'mean_integ_prf': 133.4375,
#   'std_dev_integ_prf': 55.67480214,
#   'ex_kurtosis_integ_prf': -0.06702999700000001,
#   'sk_integ_prf': -0.612488412,
#   'mean_dm_snr_curve': 1.6513377930000002,
#   'std_dev_dm_snr_curve': 13.51617413,
#   'ex_kurtosis_dm_snr_curve': 11.20794102,
#   'sk_dm_snr_curve': 157.5869616,
#   'target_class': 0.0},
#  {'mean_integ_prf': 110.09375,
#   'std_dev_integ_prf': 49.86018538,
#   'ex_kurtosis_integ_prf': 0.231684803,
#   'sk_integ_prf': 0.023331743,
#   'mean_dm_snr_curve': 2.867056856,
#   'std_dev_dm_snr_curve': 17.56549764,
#   'ex_kurtosis_dm_snr_curve': 9.45823768,
#   'sk_dm_snr_curve': 104.6663224,
#   'target_class': 0.0},
#  {'mean_integ_prf': 135.9375,
#   'std_dev_integ_prf': 41.73891133,
#   'ex_kurtosis_integ_prf': 0.025816079,
#   'sk_integ_prf': 0.389098105,
#   'mean_dm_snr_curve': 22.35702341,
#   'std_dev_dm_snr_curve': 51.46766163,
#   'ex_kurtosis_dm_snr_curve': 2.125620536,
#   'sk_dm_snr_curve': 3.1936006580000003,
#   'target_class': 0.0},
#  {'mean_integ_prf': 130.921875,
#   'std_dev_integ_prf': 54.6087804,
#   'ex_kurtosis_integ_prf': 0.188709348,
#   'sk_integ_prf': -0.393521033,
#   'mean_dm_snr_curve': 2.565217391,
#   'std_dev_dm_snr_curve': 15.882878,
#   'ex_kurtosis_dm_snr_curve': 8.447488171,
#   'sk_dm_snr_curve': 88.02420954,
#   'target_class': 0.0},
#  {'mean_integ_prf': 113.515625,
#   'std_dev_integ_prf': 47.44157334,
#   'ex_kurtosis_integ_prf': 0.348612088,
#   'sk_integ_prf': -0.000778493,
#   'mean_dm_snr_curve': 0.415551839,
#   'std_dev_dm_snr_curve': 8.305439585,
#   'ex_kurtosis_dm_snr_curve': 26.26787395,
#   'sk_dm_snr_curve': 760.2654252,
#   'target_class': 0.0},
#  {'mean_integ_prf': 110.2734375,
#   'std_dev_integ_prf': 52.21690262,
#   'ex_kurtosis_integ_prf': 0.109555025,
#   'sk_integ_prf': -0.218648333,
#   'mean_dm_snr_curve': 2.420568562,
#   'std_dev_dm_snr_curve': 13.69207025,
#   'ex_kurtosis_dm_snr_curve': 9.334918905,
#   'sk_dm_snr_curve': 121.7696645,
#   'target_class': 0.0},
#  {'mean_integ_prf': 126.2578125,
#   'std_dev_integ_prf': 50.73695123,
#   'ex_kurtosis_integ_prf': -0.094357897,
#   'sk_integ_prf': -0.453287087,
#   'mean_dm_snr_curve': 3.037625418,
#   'std_dev_dm_snr_curve': 21.18885669,
#   'ex_kurtosis_dm_snr_curve': 8.545733956,
#   'sk_dm_snr_curve': 79.30210209,
#   'target_class': 0.0},
#  {'mean_integ_prf': 109.203125,
#   'std_dev_integ_prf': 50.47405883,
#   'ex_kurtosis_integ_prf': 0.331835271,
#   'sk_integ_prf': -0.23691915,
#   'mean_dm_snr_curve': 1.4941471569999998,
#   'std_dev_dm_snr_curve': 11.69165437,
#   'ex_kurtosis_dm_snr_curve': 12.40858592,
#   'sk_dm_snr_curve': 210.1418619,
#   'target_class': 0.0},
#  {'mean_integ_prf': 125.40625,
#   'std_dev_integ_prf': 44.52342036,
#   'ex_kurtosis_integ_prf': 0.097844171,
#   'sk_integ_prf': 0.210728965,
#   'mean_dm_snr_curve': 13.76003344,
#   'std_dev_dm_snr_curve': 44.41287485,
#   'ex_kurtosis_dm_snr_curve': 3.174269187,
#   'sk_dm_snr_curve': 8.821572197,
#   'target_class': 0.0},
#  {'mean_integ_prf': 109.828125,
#   'std_dev_integ_prf': 51.30562673,
#   'ex_kurtosis_integ_prf': 0.074724818,
#   'sk_integ_prf': -0.05692356,
#   'mean_dm_snr_curve': 1.574414716,
#   'std_dev_dm_snr_curve': 12.51007544,
#   'ex_kurtosis_dm_snr_curve': 11.8089378,
#   'sk_dm_snr_curve': 179.2747478,
#   'target_class': 0.0},
#  {'mean_integ_prf': 127.0234375,
#   'std_dev_integ_prf': 50.84312036,
#   'ex_kurtosis_integ_prf': 0.519548542,
#   'sk_integ_prf': 0.031692416,
#   'mean_dm_snr_curve': 4.5326086960000005,
#   'std_dev_dm_snr_curve': 24.8687479,
#   'ex_kurtosis_dm_snr_curve': 7.405016194,
#   'sk_dm_snr_curve': 59.0834081,
#   'target_class': 0.0},
#  {'mean_integ_prf': 110.6484375,
#   'std_dev_integ_prf': 48.93803318,
#   'ex_kurtosis_integ_prf': 0.229290198,
#   'sk_integ_prf': 0.099172528,
#   'mean_dm_snr_curve': 2.128762542,
#   'std_dev_dm_snr_curve': 14.5768684,
#   'ex_kurtosis_dm_snr_curve': 11.36908626,
#   'sk_dm_snr_curve': 165.52366519999995,
#   'target_class': 0.0},
#  {'mean_integ_prf': 105.5546875,
#   'std_dev_integ_prf': 48.25434057,
#   'ex_kurtosis_integ_prf': 0.365511233,
#   'sk_integ_prf': 0.301907134,
#   'mean_dm_snr_curve': 0.719899666,
#   'std_dev_dm_snr_curve': 9.729844375,
#   'ex_kurtosis_dm_snr_curve': 18.88962216,
#   'sk_dm_snr_curve': 427.7396167,
#   'target_class': 0.0},
#  {'mean_integ_prf': 99.4296875,
#   'std_dev_integ_prf': 37.00647823,
#   'ex_kurtosis_integ_prf': 0.559514758,
#   'sk_integ_prf': 1.821466571,
#   'mean_dm_snr_curve': 5.204013378,
#   'std_dev_dm_snr_curve': 29.07745712,
#   'ex_kurtosis_dm_snr_curve': 6.022441921,
#   'sk_dm_snr_curve': 36.89268893,
#   'target_class': 0.0},
#  ...]

# %%
# separate target
target = df['target'].copy()

# split into train and test
X_train,X_test,y_train,y_test = train_test_split(
  df,
  target,
  train_size = 0.8,
  test_size = 0.2,
  random_state = 0,
  shuffle = True
)

# convert all back to DataFrame / Series
X_train = pd.DataFrame(X_train,columns=features)
X_test  = pd.DataFrame(X_test,columns=features)
y_train = pd.Series(y_train)
y_test  = pd.Series(y_test)
